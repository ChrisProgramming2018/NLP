# %% [markdown]
# # Sentiment Analysis
#
# _Artificial Intelligence Nanodegree Program | Natural Language Processing_
#
# ---
#
# With the rise of online social media platforms like Twitter, Facebook and Reddit, and the proliferation of customer reviews on sites like Amazon and Yelp, we now have access, more than ever before, to massive text-based data sets! They can be analyzed in order to determine how large portions of the population feel about certain products, events, etc. This sort of analysis is called _sentiment analysis_. In this notebook you will build an end-to-end sentiment classification system from scratch.
#
# ## Instructions
#
# Some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this notebook. You will not need to modify the included code beyond what is requested. Sections that begin with '**TODO**' in the header indicate that you need to complete or implement some portion within them. Instructions will be provided for each section and the specifics of the implementation are marked in the code block with a `# TODO: ...` comment. Please be sure to read the instructions carefully!
#
# In addition to implementing code, there will be questions for you to answer which relate to the task and your implementation. Each section where you will answer a question is preceded by a '**Question:**' header. Carefully read each question and provide your answer below the '**Answer:**' header by editing the Markdown cell.
#
# > **Note**: Code and Markdown cells can be executed using the **Shift+Enter** keyboard shortcut. In addition, a cell can be edited by typically clicking it (double-click for Markdown cells) or by pressing **Enter** while it is highlighted.

# %% [markdown]
# ## Step 1: Exploring the data!
#
# The dataset we are going to use is very popular among researchers in Natural Language Processing, usually referred to as the [IMDb dataset](http://ai.stanford.edu/~amaas/data/sentiment/). It consists of movie reviews from the website [imdb.com](http://www.imdb.com/), each labeled as either '**pos**itive', if the reviewer enjoyed the film, or '**neg**ative' otherwise.
#
# > Maas, Andrew L., et al. [Learning Word Vectors for Sentiment Analysis](http://ai.stanford.edu/~amaas/data/sentiment/). In _Proceedings of the 49th Annual Meeting of the Association for Computational Linguistics: Human Language Technologies_. Association for Computational Linguistics, 2011.
#
# We have provided the dataset for you. You can load it in by executing the Python cell below.

# %%
import os
import glob

def read_imdb_data(data_dir='data/imdb-reviews'):
    """Read IMDb movie reviews from given directory.
    
    Directory structure expected:
    - data/
        - train/
            - pos/
            - neg/
        - test/
            - pos/
            - neg/
    
    """

    # Data, labels to be returned in nested dicts matching the dir. structure
    data = {}
    labels = {}

    # Assume 2 sub-directories: train, test
    for data_type in ['train', 'test']:
        data[data_type] = {}
        labels[data_type] = {}

        # Assume 2 sub-directories for sentiment (label): pos, neg
        for sentiment in ['pos', 'neg']:
            data[data_type][sentiment] = []
            labels[data_type][sentiment] = []
            
            # Fetch list of files for this sentiment
            path = os.path.join(data_dir, data_type, sentiment, '*.txt')
            files = glob.glob(path)
            
            # Read reviews data and assign labels
            for f in files:
                with open(f) as review:
                    data[data_type][sentiment].append(review.read())
                    labels[data_type][sentiment].append(sentiment)
            
            assert len(data[data_type][sentiment]) == len(labels[data_type][sentiment]), \
                    "{}/{} data size does not match labels size".format(data_type, sentiment)
    
    # Return data, labels as nested dicts
    return data, labels


data, labels = read_imdb_data()
print("IMDb reviews: train = {} pos / {} neg, test = {} pos / {} neg".format(
        len(data['train']['pos']), len(data['train']['neg']),
        len(data['test']['pos']), len(data['test']['neg'])))
# Out:
# IMDb reviews: train = 12500 pos / 12500 neg, test = 12500 pos / 12500 neg

# %% [markdown]
# Now that the data is loaded in, let's take a quick look at one of the positive reviews:

# %%
print(data['train']['pos'][2])
# Out:
# Excellent story about teenagers, leaders, high school football "stars". How far will you go to protect your friends? Lie, kill? How much can You lose if you stud by an innocent girl? Can love beat the odds? Can you defeat narrow-minded small town people? When your friend scores and you "lose", will you do everything in your power to make her pay for it, or will you be a man about it, and respect her right to chose? Will you rape her and show it as your victory over a "problem" girl? Can you stand by the one who's only sin is to have an opinion of her own, to be able to make her own decisions, to chose for herself? It made me think twice before giving my judgment about who was right and who was wrong, but one is for sure - very disturbing movie and theme in general. Thumb up!

# %% [markdown]
# And one with a negative sentiment:

# %%
print(data['train']['neg'][2])
# Out:
# The Tooth Fairy is set in a small town somewhere in Northern California where Peter Campbell (Lochlyn Munro) has brought a farming property which he is renovating & planning to turn into a holiday inn, he is joined by his girlfriend Darcy Wagner (Chandra West) & her young 12 year old daughter Pamela (Nicole Munoz) who arrive to help for the weekend. While exploring the property Pamela meets another young girl named Emma (Jianna Ballard) who warns her that evil lurks within her new home, she tells a tale of an evil old witch known as the Tooth Fairy who takes baby teeth from children & then kills them. Pamela is worried & becomes even more so when she falls off her bike & her last baby tooth falls out, it's not long before the evil ghost of the Tooth Fairy has her eyes on Pamela's tooth & just for kicks she also decides to kill anyone she comes across...<br /><br />Directed by Chuck Bowman I thought The Tooth Fairy was just another poor straight-to-video low budget horror film that fails to distinguish itself from the countless other's which litter video shop shelves & fill late night obscure cable TV schedules, basically it's not very good. The script by producer Stephen J. Cannell, Corey Strode & Cookie Rae Brown is a complete snooze-fest for the first 40 odd minutes, nothing of any great interest happen during this period at all & is basically dull exposition as if this stuff was going to surprise anyone. It introduces the character's, sets the Tooth Fairy legend up & that's it. The second half of the film improves slightly but even then it's hardly spectacular stuff, there are a few decent set-piece gore scenes but apart from that it's all very predictable & forgettable stuff. The character's aren't great & most of them are there purely to be killed off, the story has inconsistencies like the story of the Tooth Fairy herself, it says she kills children after they give her their baby teeth so why does she go on an indiscriminate killing spree that has nothing to do with teeth? What happened to her after the prologue set during 1949? Why has she come back as a ghost? Despite being a ghost of some sort she seems very human having to open doors herself & using weapons to kill people, there is no attempt to make any use of the supernatural elements except the ghostly children who are played for maximum sentiment.<br /><br />Director Bowman does OK, it's reasonably well made & there are a couple of half decent scenes but nothing to get that excited about. There's nothing I would describe as scary or atmospheric in here & don't take any notice of the comparisons between this & Darkness Falls (2003) as besides the teeth thing they're quite different. The gore is OK, someone is shoved into a wood-chipping machine, there's a decapitation, someone has their penis chopped off & the best scene when someone is nailed to a door & then has their stomach hacked open with an axe & their guts slide out.<br /><br />With a supposed budget of about $1,500,000 The Tooth Fairy is generally well made but there's nothing special on show here. The acting isn't anything great but it's not too bad & unusually I didn't find the child actors that annoying so that's something I suppose.<br /><br />The Tooth Fairy is the usual just below average low budget modern straight-to-video horror fare that seems everywhere these days, if you can find a cheap copy then it might pass 90 odd minutes if your not too demanding otherwise it's pretty poor & forgettable stuff.

# %% [markdown]
# We can also make a wordcloud visualization of the reviews.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from wordcloud import WordCloud, STOPWORDS

sentiment = 'pos'

# Combine all reviews for the desired sentiment
combined_text = " ".join([review for review in data['train'][sentiment]])

# Initialize wordcloud object
wc = WordCloud(background_color='white', max_words=50,
        # update stopwords to include common words like film and movie
        stopwords = STOPWORDS.update(['br','film','movie', 'one', 'see', 'make', 'time']))

# Generate and plot wordcloud
plt.imshow(wc.generate(combined_text))
plt.axis('off')
plt.show()

# %% [markdown]
# Try changing the sentiment to `'neg'` and see if you can spot any obvious differences between the wordclouds.

# %%
sentiment = 'neg'

combined_text_neg = " ".join([review for review in data['train'][sentiment]])
wc =  WordCloud(max_words=50)
ob = wc.generate(combined_text)

# %%
plt.imshow(ob)
plt.show()

# %% [markdown]
# ### TODO: Form training and test sets
#
# Now that you've seen what the raw data looks like, combine the positive and negative documents to get one unified training set and one unified test set.

# %%
from sklearn.utils import shuffle

def prepare_imdb_data(data):
    """Prepare training and test sets from IMDb movie reviews."""
    
    # TODO: Combine positive and negative reviews and labels
    data_train = data['train']['neg'] + data['train']['pos']
    data_test = data['test']['neg'] + data['test']['pos']
   
    labels_train = labels['train']['neg'] + labels['train']['pos']
    labels_test = labels['test']['neg'] + labels['test']['pos']
    # TODO: Shuffle reviews and corresponding labels within training and test sets
        
    # Return a unified training data, test data, training labels, test labets
    data_train, labels_train = shuffle(data_train, labels_train)
    data_test , labels_test = shuffle(data_test, labels_test)    
    return data_train, data_test, labels_train, labels_test


data_train, data_test, labels_train, labels_test = prepare_imdb_data(data)
print("IMDb reviews (combined): train = {}, test = {}".format(len(data_train), len(data_test)))
# Out:
# IMDb reviews (combined): train = 25000, test = 25000

# %% [markdown]
# ## Step 2. Preprocessing
#
# As you might have noticed in the sample reviews, our raw data includes HTML. Therefore there are HTML tags that need to be removed. We also need to remove non-letter characters, normalize uppercase letters by converting them to lowercase, tokenize, remove stop words, and stem the remaining words in each document.
#
# ### TODO: Convert each review to words
#
# As your next task, you should complete the function `review_to_words()` that performs all these steps. For your convenience, in the Python cell below we provide you with all the libraries that you may need in order to accomplish these preprocessing steps. Make sure you can import all of them! (If not, pip install from a terminal and run/import again.)

# %%
# BeautifulSoup to easily remove HTML tags
from bs4 import BeautifulSoup 
import  sys
# RegEx for removing non-letter characters
import re

# NLTK library for the remaining steps
import nltk
nltk.download("stopwords")   # download list of stopwords (only once; need not run it again)
from nltk.corpus import stopwords # import stopwords

from nltk.stem.porter import *
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to /home/info/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# create stopword dict
stop_dict = { x : 1for x in stopwords.words()}

# %%
i =0
length = len(data_test)
def review_to_words(review):
    """Convert a raw review string into a sequence of words."""
    
    # TODO: Remove HTML tags and non-letters,
    #       convert to lowercase, tokenize,
    #       remove stopwords and stem
    clean_text = re.sub("[^A-Za-z]", " ", review)
    global i
    global length
    i = i+1 
    sys.stdout.write(" progress the: %d  of %d  \r" % (i, length) )
    sys.stdout.flush()
    words = []
    for word in clean_text.split(' '):
        if word in stop_dict or len(word) <= 2:
            continue
        words.append(word.lower())
    # Return final list of words
    return words


review_to_words("""This is just a <em>test</em>.<br/><br />
But if it wasn't a test, it would make for a <b>Great</b> movie review!""")
# Out:
#  progress the: 1  of 25000
# ['this', 'test', 'but', 'test', 'would', 'make', 'great', 'movie', 'review']

# %% [markdown]
# With the function `review_to_words()` fully implemeneted, we can apply it to all reviews in both training and test datasets. This may take a while, so let's build in a mechanism to write to a cache file and retrieve from it later.

# %%
import pickle

cache_dir = os.path.join("cache", "sentiment_analysis")  # where to store cache files
os.makedirs(cache_dir, exist_ok=True)  # ensure cache directory exists

def preprocess_data(data_train, data_test, labels_train, labels_test,
                    cache_dir=cache_dir, cache_file="preprocessed_data.pkl"):
    """Convert each review to words; read from cache if available."""

    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = pickle.load(f)
            print("Read preprocessed data from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Preprocess training and test data to obtain words for each review
        words_train = list(map(review_to_words, data_train))
        words_test = list(map(review_to_words, data_test))
        
        # Write to cache file for future runs
        if cache_file is not None:
            cache_data = dict(words_train=words_train, words_test=words_test,
                              labels_train=labels_train, labels_test=labels_test)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                pickle.dump(cache_data, f)
            print("Wrote preprocessed data to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        words_train, words_test, labels_train, labels_test = (cache_data['words_train'],
                cache_data['words_test'], cache_data['labels_train'], cache_data['labels_test'])
    
    return words_train, words_test, labels_train, labels_test

# %%
# Preprocess data
words_train, words_test, labels_train, labels_test = preprocess_data(
        data_train, data_test, labels_train, labels_test)

# Take a look at a sample
print("\n--- Raw review ---")
print(data_train[1])
print("\n--- Preprocessed words ---")
print(words_train[1])
print("\n--- Label ---")
print(labels_train[1])
# Out:
# Read preprocessed data from cache file: preprocessed_data.pkl
#
# --- Raw review ---
# At first glance, this movie has got everything a psycho wants: a vampire story with a "not under 18" restriction, filled with hyper-violence, drugs, gore, sex (including lesbian sex), some fanatics zealots and even a gay necrophiliac cop! But then, this movie is a succession of bad story (so thin), bad acting -with a ridiculous english accent making you believe you're watching a bad Monty Python -, bad music ('80s hard rock), the videotaping is awful, the ending is a real shame... Plus the scenes of sex are ridiculous, the gore not very impressive. And those vampires reflect in a mirror, and don't even fear daylight! You get to be very disappointed, unless you see it as a "Space Mutiny" or "Troll 2". I hope Bloodlust will one day reach the bottom 100, because that's its real place.<br /><br />I'd say it can still be fun to watch, if you have friends and enough beer.<br /><br />3/10
#
# --- Preprocessed words ---
# ['from', 'beginning', 'movie', 'flaws', 'the', 'main', 'character', 'played', 'hayden', 'christensen', 'rich', 'young', 'mogul', 'inherited', 'father', 'considerable', 'wealth', 'power', 'struggling', 'fill', 'father', 'shoes', 'cut', 'apron', 'strings', 'mother', 'executive', 'keeps', 'tight', 'problem', 'heart', 'condition', 'waiting', 'limbo', 'organ', 'donor', 'registry', 'there', 'minor', 'back', 'stories', 'first', 'instinct', 'mostly', 'ignore', 'become', 'important', 'later', 'friendship', 'surgeon', 'terrence', 'howard', 'romance', 'middle', 'class', 'girl', 'jessica', 'alba', 'uncreative', 'story', 'lines', 'bad', 'enough', 'ruin', 'movie', 'the', 'real', 'vey', 'moment', 'name', 'lena', 'olin', 'character', 'overbearing', 'woman', 'named', 'lilith', 'subtle', 'the', 'surgical', 'scenes', 'censored', 'appreciated', 'people', 'find', 'surgery', 'scenes', 'scary', 'might', 'the', 'horror', 'awake', 'anesthesia', 'done', 'well', 'first', 'you', 'watch', 'emotional', 'agony', 'christensen', 'screams', 'inwardly', 'chest', 'incision', 'rib', 'spreader', 'the', 'moment', 'irony', 'trailers', 'comes', 'one', 'unlucky', 'awake', 'anesthesia', 'luck', 'helps', 'learn', 'surgical', 'team', 'planning', 'murder', 'the', 'big', 'twist', 'however', 'predictable', 'sends', 'film', 'delving', 'conspiracy', 'memories', 'little', 'signs', 'like', 'initially', 'missed', 'there', 'two', 'twists', 'involving', 'relationship', 'mother', 'one', 'impressive', 'gesture', 'olin', 'comes', 'unimpressive', 'due', 'poor', 'writing', 'the', 'secret', 'family', 'past', 'seemed', 'tacked', 'pointless', 'the', 'initially', 'well', 'done', 'anesthesia', 'awareness', 'drama', 'gets', 'lost', 'poorly', 'written', 'conspiracy', 'drama', 'there', 'one', 'final', 'attempt', 'bring', 'back', 'falls', 'flat', 'taking', 'entire', 'movie']
#
# --- Label ---
# neg

# %% [markdown]
# ## Step 3: Extracting Bag-of-Words features
#
# Now that each document has been preprocessed, we can transform each into a Bag-of-Words feature representation. Note that we need to create this transformation based on the training data alone, as we are not allowed to peek at the testing data at all!
#
# The dictionary or _vocabulary_ $V$ (set of words shared by documents in the training set) used here will be the one on which we train our supervised learning algorithm. Any future test data must be transformed in the same way for us to be able to apply the learned model for prediction. Hence, it is important to store the transformation / vocabulary as well.
#
# > **Note**: The set of words in the training set may not be exactly the same as the test set. What do you do if you encounter a word during testing that you haven't seen before? Unfortunately, we'll have to ignore it, or replace it with a special `<UNK>` token.
#
# ### TODO: Compute Bag-of-Words features
#
# Implement the `extract_BoW_features()` function, apply it to both training and test datasets, and store the results in `features_train` and `features_test` NumPy arrays, respectively. Choose a reasonable vocabulary size, say $|V| = 5000$, and keep only the top $|V|$ occuring words and discard the rest. This number will also serve as the number of columns in the BoW matrices.
#
# > **Hint**: You may find it useful to take advantage of `CountVectorizer` from scikit-learn. Also make sure to pickle your Bag-of-Words transformation so that you can use it in future.

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.externals import joblib
# joblib is an enhanced version of pickle that is more efficient for storing NumPy arrays

# %%
len(words_train)
# Out:
# 25000

# %%
cv = CountVectorizer()

# %%
big_list = []
for text in words_train:
    for word in text:
        big_list.append(word)

# %%
len(big_list)
# Out:
# 3048335

# %%
cv.fit_transform(raw_documents= big_list)
# Out:
# <3048335x72705 sparse matrix of type '<class 'numpy.int64'>'
# 	with 3048335 stored elements in Compressed Sparse Row format>

# %%
for key in cv.vocabulary_.keys():
    print(key, cv.vocabulary_[key])
# Out:
# lothario 37854
# shrug 58041
# intrigued 32740
# garnell 25406
# latex 36244
# breadbasket 7723
# mayron 39869
# linguist 37268
# bild 6146
# refreshes 52515
# bushwacker 8651
# reminiscing 52939
# elways 20082
# caution 9940
# copolla 13506
# additional 627
# recollecting 52207
# sabotaged 55102
# pinpoint 48245
# normal 44255
# dramatisation 18663
# philosophise 47892
# cremation 14240
# endowed 20452
# lin 37206
# blockbuster 6645
# womans 71422
# rattlesnakes 51779
# rigidity 53982
# fort 24236
# sevens 57154
# monceau 41866
# astronomically 3599
# friction 24659
# reprisals 53198
# bennie 5706
# snider 59333
# dehumanized 15960
# slivers 58982
# knuckler 35326
# cheyney 10759
# payoffs 47066
# meaninglessly 40155
# jars 33461
# naturalistic 43300
# tensely 64100
# tavernier 63720
# pistilli 48310
# roobi 54507
# muffin 42573
# mailed 38690
# pris 49906
# overpowered 45992
# parliament 46697
# sensed 56904
# eurocrime 21288
# erupting 21037
# nyqvist 44621
# goyas 26835
# lawnmowers 36386
# tukur 66518
# connect 12953
# professione 50064
# malte 38889
# gibbons 25969
# redeaming 52332
# manly 39084
# payer 47057
# thirty 64586
# battlecry 5097
# essaying 21150
# gangsters 25317
# lope 37800
# unbearableness 67087
# clunkiness 11776
# ruler 54896
# ascendant 3338
# tobe 65158
# duking 19058
# obscessed 44734
# mount 42395
# labels 35750
# asquith 3433
# handedness 28170
# socialistic 59489
# classes 11446
# flava 23554
# ninga 44001
# tera 64136
# legality 36598
# jest 33672
# princess 49878
# earmark 19387
# scarwid 55941
# jailer 33319
# playfulness 48517
# reachable 51898
# mistake 41533
# wwwf 71840
# ached 423
# hunched 30596
# melisa 40393
# demise 16142
# bertrand 5848
# grout 27398
# crisis 14330
# warren 70125
# divinely 17958
# blares 6496
# unlikeable 67826
# jelous 33595
# komodo 35387
# peoples 47355
# snuck 59432
# dolby 18171
# semisubmerged 56849
# askeys 3408
# remembrance 52919
# adultery 811
# jahfre 33311
# costarring 13759
# zhukov 72526
# ovas 45837
# clubbers 11751
# straying 61612
# wardens 70058
# transit 65839
# stagy 60779
# mostly 42310
# sidearms 58171
# empt 20308
# harnessed 28431
# goosebump 26690
# onwards 45217
# unshakeable 68127
# stew 61238
# hungama 30603
# viewings 69309
# condoning 12782
# rys 55066
# deeds 15757
# hilarity 29457
# disfunction 17524
# hyrum 30819
# advanced 819
# teffe 63900
# barrimore 4911
# hammily 28129
# periodical 47473
# abruptly 197
# daze 15429
# satanism 55669
# constrains 13131
# millionare 41110
# louis 37892
# slowdown 59043
# orientations 45502
# mummifies 42696
# life 37051
# revealingly 53619
# debated 15542
# spearheads 60111
# reused 53608
# greta 27170
# moisturiser 41776
# wedge 70382
# heaviest 28859
# males 38829
# steinem 61134
# soiree 59587
# lordly 37814
# anywayz 2592
# slits 58978
# salivating 55326
# lungren 38184
# user 68498
# rillington 54008
# effusive 19698
# celaschi 10038
# thai 64318
# authenic 3920
# forsyth 24233
# filmdirector 23144
# yuppy 72322
# overthrows 46075
# heiresses 28981
# bissonnette 6307
# haydon 28670
# danielsen 15189
# corsia 13706
# quaint 50986
# bombarded 7075
# mollified 41816
# decodes 15685
# energised 20474
# chimney 10862
# carlucci 9510
# unfinished 67573
# linklaters 37279
# posting 49222
# kafi 34287
# stormriders 61478
# eternity 21225
# patronising 46968
# ner 43610
# wort 71637
# desantis 16463
# shearsmith 57517
# brittle 7999
# enthusast 20708
# carlottai 9506
# leukemia 36870
# nefretiri 43493
# voracious 69717
# consist 13071
# refusal 52538
# muito 42594
# extravagances 21992
# nietsche 43893
# lifeguard 37058
# nickname 43849
# reshammiya 53313
# ferhan 22862
# judson 34085
# paramilitarian 46589
# dell 16069
# tilman 64933
# jayhawkers 33505
# privilege 49933
# starry 60955
# tenuously 64121
# kya 35722
# behave 5462
# philisophic 47867
# declines 15679
# lasagna 36180
# barmen 4854
# mumbler 42687
# cryptology 14600
# jezuz 33715
# cause 9934
# fletcher 23623
# hebetude 28870
# ramirez 51534
# overdubs 45907
# academia 277
# brevet 7833
# defuse 15925
# unforunatley 67618
# ripstein 54083
# rebuffed 52087
# consulting 13161
# kounen 35487
# boyscout 7536
# confederate 12808
# comcastic 12235
# boosh 7258
# woodfin 71468
# brethern 7826
# microscopically 40909
# themsleves 64418
# nobodies 44090
# python 50948
# who 70847
# fastidiously 22530
# hartley 28486
# atlas 3673
# marybeth 39511
# visage 69494
# excellently 21541
# ravers 51819
# grant 26980
# contacting 13184
# grinned 27269
# encompasses 20380
# kanefsky 34379
# davonne 15394
# horner 30137
# conflated 12853
# toker 65218
# deteriorate 16662
# typewriters 66807
# hah 27927
# ignite 31005
# eagerness 19358
# drowns 18892
# affaire 915
# sanpro 55537
# enveloped 20787
# sniggering 59346
# apricorn 2849
# sorcha 59823
# characterizations 10410
# metallers 40730
# cosimos 13733
# immortally 31225
# rinna 54041
# timberlake 64945
# papamoschou 46504
# outlandishly 45730
# industrialized 31860
# emory 20249
# dimension 17154
# tanking 63533
# vadis 68614
# hertzfeldt 29259
# enjoyable 20566
# sufferer 62223
# satellite 55678
# cataloging 9800
# cassie 9742
# matheau 39700
# krusty 35605
# drivas 18833
# lab 35743
# beachcombers 5178
# medal 40215
# serendipitous 57035
# critic 14358
# billboards 6160
# handgun 28175
# supremes 62627
# palace 46312
# reign 52672
# augmented 3850
# wishlist 71254
# karmic 34460
# luckless 38064
# contradictions 13302
# hale 28007
# harding 28352
# approximate 2840
# sayers 55826
# merim 40617
# wasting 70188
# miniscule 41233
# tricksy 66156
# mistrust 41553
# coven 13940
# grandnes 26964
# ppl 49362
# columnists 12198
# tactics 63285
# gage 25119
# falls 22258
# dillute 17139
# horrifyingly 30170
# rightwing 53980
# inconsiderately 31642
# aerobics 888
# carrer 9590
# gener 25650
# courrieres 13902
# everything 21399
# gassing 25466
# barman 4852
# integration 32438
# deeper 15774
# potok 49284
# pectoral 47150
# lump 38146
# unsurpassed 68187
# cluelessness 11762
# keener 34646
# crock 14398
# kelley 34689
# dias 16930
# drexler 18789
# appreciatted 2808
# somerset 59699
# devry 16831
# workforce 71562
# feint 22756
# something 59704
# quartet 51044
# eyeliner 22051
# teegra 63867
# sesilia 57112
# molding 41794
# srbljanovic 60702
# ayacoatl 4155
# addition 626
# seamy 56538
# tour 65574
# betrays 5918
# blabbermouth 6360
# terribilisms 64180
# handling 28193
# abstractions 240
# teeenage 63866
# ghazals 25896
# bowlers 7500
# whitney 70832
# pintilie 48252
# iwo 33204
# complication 12554
# batchler 5049
# favorably 22607
# karlof 34455
# money 41881
# hoshi 30227
# handheld 28177
# nightgown 43921
# mary 39509
# anthropomorphized 2474
# admonition 743
# hamwork 28153
# sharps 57460
# speed 60186
# claw 11494
# unannounced 67043
# venture 69013
# mohanlal 41759
# spire 60326
# calibanian 8977
# greenlights 27129
# lodgers 37577
# allusive 1628
# retopologizes 53557
# westerberg 70578
# clippings 11651
# validate 68678
# emo 20248
# skillfully 58681
# sokorowska 59593
# loulou 37899
# bludge 6768
# loyalties 38009
# decaying 15609
# serling 57069
# federal 22703
# inches 31561
# unbearably 67088
# prohibition 50131
# gertr 25847
# londoner 37672
# brandon 7641
# suckiness 62186
# cyborg 14908
# suspected 62764
# yasbeck 72012
# memorise 40465
# guitars 27613
# fusion 25020
# boyars 7523
# spam 60017
# orifices 45504
# gonzolez 26616
# adams 593
# eulogy 21270
# selick 56802
# clinton 11642
# honed 29971
# overstay 46055
# rana 51570
# godlike 26471
# rambos 51522
# invigored 32857
# wads 69838
# stevson 61237
# hobbyhorse 29709
# giuliani 26163
# bounds 7460
# brazen 7712
# outsource 45803
# dusky 19231
# loonie 37754
# cajoling 8926
# hoffbrauhaus 29746
# punjab 50733
# academies 281
# unwaveringly 68284
# dulled 19065
# wealth 70323
# indestructibility 31751
# liswood 37371
# desoto 16552
# normality 44257
# scola 56236
# horribleness 30157
# revisits 53690
# acoustic 477
# masts 39643
# indiscretionary 31802
# charli 10463
# paste 46859
# destructed 16621
# naziism 43379
# balkanic 4532
# fervent 22911
# hattori 28593
# holograms 29871
# scarf 55920
# manifests 39054
# grist 27290
# melania 40372
# trilateralists 66178
# upsetting 68387
# packenham 46197
# dolomites 18198
# charitable 10447
# coilition 11996
# schnook 56114
# james 33351
# therefore 64467
# kosugis 35473
# estimate 21192
# sodebergh 59528
# eachother 19353
# dusk 19229
# inuindo 32780
# karfreitag 34444
# trait 65746
# barretto 4901
# stein 61129
# comstock 12642
# visuals 69549
# evolvement 21449
# emplacement 20288
# terminal 64152
# keither 34678
# plussed 48694
# license 37008
# treasures 66008
# dillemma 17131
# stems 61150
# condsidering 12786
# obi 44675
# phycho 47978
# cias 11177
# roughshod 54700
# fateful 22549
# headroom 28751
# incongruously 31636
# borzage 7368
# prologic 50162
# claustraphobia 11486
# shinjuku 57713
# yoke 72179
# vacate 68583
# ipanema 32911
# halted 28083
# shachnovelle 57245
# norwegians 44296
# speeders 60191
# laptop 36124
# caucasian 9914
# assassinating 3449
# teek 63868
# published 50591
# discretion 17474
# okish 45054
# gigolos 26014
# manco 38953
# congregating 12919
# scrawl 56347
# bachstage 4279
# proudly 50388
# seiing 56752
# cinematographic 11253
# preempted 49548
# bans 4717
# archival 2958
# shutterbug 58095
# liceman 37004
# yog 72168
# bovasso 7478
# autobiographical 3952
# stringy 61713
# manufactures 39154
# benis 5691
# modus 41736
# expert 21798
# vilsmaier 69389
# jerry 33660
# punishable 50726
# slurping 59082
# shlop 57795
# program 50107
# ivanna 33187
# telephone 63943
# harpy 28449
# avoiding 4070
# nard 43197
# lesbians 36812
# unchoreographed 67162
# zhi 72518
# jugs 34098
# ticaks 64846
# essanay 21146
# differing 17044
# roughing 54694
# changs 10345
# isha 33055
# deprive 16388
# stygian 61921
# megazord 40331
# sorcerer 59818
# viscously 69508
# straightening 61533
# griever 27205
# cables 8837
# kimberley 34986
# provinces 50412
# harrass 28452
# wach 69808
# thats 64358
# shazbot 57506
# maddern 38498
# neecessary 43471
# dirk 17290
# barbed 4775
# orgasmic 45482
# englishness 20530
# gouden 26788
# straitjacket 61549
# rankled 51617
# contradicting 13300
# pickens 48031
# central 10131
# gauguin 25506
# mccenna 39929
# pool 48991
# synagogue 63143
# metcalfe 40756
# cliver 11661
# turks 66611
# marxist 39507
# subsuming 62093
# crimelord 14292
# crowne 14495
# cranberry 14069
# kenyon 34741
# hoky 29784
# apr 2847
# fresher 24630
# reunited 53603
# damnation 15114
# unreasonably 68023
# mulling 42635
# cryogenically 14594
# sad 55158
# didn 17002
# cran 14067
# meaningful 40149
# shakespeare 57308
# tyold 66797
# compass 12459
# ato 3689
# hoek 29740
# newscaster 43749
# blurry 6813
# jama 33344
# cheater 10580
# badd 4352
# starbucks 60913
# storyteller 61498
# falon 22260
# tooltime 65353
# hepcats 29144
# elija 19961
# popularize 49049
# columbu 12191
# monocle 41925
# jacky 33264
# unattached 67065
# lateesha 36235
# figgy 23072
# halloway 28052
# commentating 12330
# seep 56708
# cyclops 14921
# discarded 17386
# unwed 68285
# superego 62467
# weathered 70350
# deployment 16349
# overexciting 45917
# avalos 4002
# rationed 51762
# devotee 16816
# dismissable 17624
# waxwork 70285
# overnite 45981
# weirdos 70472
# urbe 68428
# enrapture 20621
# sensations 56902
# maadri 38335
# gameshow 25270
# until 68224
# spookiest 60463
# kids 34922
# accepted 310
# feral 22847
# thinks 64560
# artemisia 3247
# styled 61924
# converting 13392
# soberly 59474
# mismatches 41463
# azteca 4194
# suvari 62801
# homemade 29904
# matador 39654
# fueled 24850
# grewing 27180
# sultry 62330
# pleas 48550
# deepak 15769
# measurement 40172
# patter 46979
# untraditional 68235
# busom 8671
# denison 16245
# bib 6039
# mountainous 42401
# longman 37705
# malkovichian 38857
# minor 41261
# playlist 48525
# sourpuss 59924
# shimizu 57688
# fewest 22971
# marveling 39494
# stripping 61723
# yah 71936
# daffily 14994
# dunaway 19124
# cyrus 14947
# raoul 51637
# coffeshop 11946
# puddy 50610
# unbecoming 67091
# hesitatingly 29279
# veranda 69027
# occurring 44848
# advocates 877
# glowers 26372
# nutrition 44570
# mackay 38433
# ecstasy 19545
# watterman 70261
# sacristan 55157
# productions 50044
# finals 23211
# rascally 51700
# hurtful 30669
# textured 64304
# mitb 41572
# sadists 55184
# returning 53594
# minot 41267
# commies 12353
# atoz 3702
# akte 1336
# bringing 7947
# mainframe 38707
# deluge 16097
# jailhouse 33320
# spoladore 60436
# foppishly 24036
# fidgetting 23031
# caliban 8976
# hobbies 29699
# bucharest 8263
# lexus 36931
# budget 8310
# scorpio 56273
# deadness 15471
# criticising 14365
# snuffleupagus 59436
# saalistajat 55078
# define 15877
# mutia 42888
# glover 26366
# brash 7658
# preface 49559
# poir 48785
# raucous 51785
# wealthy 70326
# babysitting 4255
# adamson 594
# cavepeople 9965
# tightrope 64910
# hassled 28531
# magically 38589
# dora 18399
# singapore 58447
# devgn 16763
# grotesuque 27369
# posterous 49218
# murnau 42777
# pei 47234
# routemaster 54731
# leath 36508
# digest 17066
# channy 10354
# nepalease 43600
# escorts 21084
# marraiges 39418
# pabst 46159
# littler 37416
# fineman 23233
# cronyn 14429
# lessens 36828
# syllable 63085
# spoilment 60426
# stinko 61330
# yolu 72189
# shorty 57917
# weeped 70415
# raised 51453
# mcmahonagement 40069
# repartees 53079
# colts 12183
# spiritedness 60331
# plaid 48413
# cyclon 14917
# freighted 24587
# catered 9854
# slowely 59045
# criminality 14296
# messanger 40692
# mouths 42438
# harrer 28455
# chelsea 10669
# cringy 14315
# insipidly 32294
# chewbacca 10750
# doright 18416
# floozies 23736
# hernando 29215
# swapped 62867
# shepherd 57603
# stooping 61439
# prowls 50436
# befuddled 5423
# kissinger 35120
# picasso 48020
# unequaled 67512
# yawnfest 72042
# judges 34074
# rader 51306
# apparenly 2707
# lent 36755
# ramming 51539
# flyswatter 23860
# bumping 8464
# screws 56398
# ross 54620
# hypothesis 30813
# khakhi 34827
# enhance 20547
# imprimatur 31415
# scarecrow 55911
# turnout 66630
# stuttgart 61914
# unsynchronised 68201
# iturbi 33177
# bowed 7486
# fees 22735
# bewitchment 5973
# obese 44669
# broccoli 8030
# pieczanski 48090
# pilfering 48150
# hurling 30653
# beluche 5621
# grabby 26852
# denver 16293
# itc 33145
# dil 17114
# viz 69600
# pincers 48196
# hen 29094
# brief 7884
# whiteley 70807
# strolls 61752
# midst 40953
# sadeqi 55176
# illuminated 31079
# reflective 52486
# danaza 15137
# expositing 21879
# bodybag 6925
# recap 52108
# jeremey 33629
# unapologetically 67048
# dogtown 18153
# stealing 61065
# macleans 38451
# bitva 6338
# dent 16277
# rudd 54840
# judgements 34073
# infamously 31923
# swimsuit 62985
# kareeena 34434
# tri 66110
# literally 37383
# trunk 66408
# sarsgaard 55633
# archiev 2947
# ganghis 25304
# wormholes 71603
# crapped 14093
# gaolers 25333
# tightwad 64912
# menahem 40481
# weepies 70419
# vaughns 68873
# dreamgirls 18735
# shemekia 57591
# morano 42126
# cigars 11197
# mine 41183
# sandbag 55461
# earplugs 19404
# gowky 26830
# ceded 10025
# scrounge 56436
# heffner 28929
# fern 22871
# lennon 36740
# browns 8141
# solomon 59658
# simple 58389
# pita 48317
# motorists 42373
# pharoah 47798
# regina 52585
# misbegotten 41342
# paramilitary 46591
# puss 50869
# glanced 26222
# womano 71421
# hoechlin 29739
# fare 22411
# nominates 44150
# subsumed 62092
# womanhood 71412
# abating 57
# enabled 20332
# stamos 60845
# millions 41111
# consciousness 13020
# markell 39343
# grammies 26921
# consideration 13058
# prop 50223
# unborn 67121
# brevity 7834
# valli 68698
# lesser 36829
# draftees 18621
# avenged 4020
# totality 65519
# mendoza 40505
# sided 58175
# donkey 18284
# lillie 37158
# unsettles 68120
# bantering 4723
# yaaa 71914
# falafel 22228
# millimeter 41104
# despatcher 16563
# fiancee 22985
# emblemized 20157
# meyler 40824
# chertkov 10710
# store 61458
# wards 70064
# rennie 53019
# hospice 30231
# houswives 30336
# deutschen 16725
# crumble 14543
# imperialists 31296
# lastly 36222
# recursive 52310
# capper 9331
# stagestruck 60765
# tolerantly 65235
# andronicus 2181
# evangalizing 21328
# whimsy 70739
# schmidtt 56095
# hod 29727
# holliman 29824
# tenfold 64080
# vansishing 68798
# hatstand 28584
# combination 12217
# psychoanalytic 50520
# approachable 2819
# modifying 41726
# asthetics 3559
# sheffer 57551
# phoned 47925
# piedras 48093
# rulezzz 54900
# travails 65958
# winterson 71201
# infinitum 31983
# caas 8813
# sulky 62314
# landy 36057
# heartbreaker 28805
# knick 35257
# postmaster 49230
# reccomened 52121
# bozo 7541
# freddie 24535
# beddoe 5331
# charisse 10445
# anholt 2274
# spring 60545
# smile 59161
# wold 71387
# hoax 29693
# desparte 16562
# zavattini 72427
# tillman 64929
# rebuttal 52099
# constitutions 13128
# mudge 42561
# cellophane 10078
# chapeau 10368
# shatter 57478
# tarus 63643
# expositionary 21882
# repetoir 53115
# represents 53183
# detonates 16698
# buccaneering 8257
# scientist 56215
# arresting 3183
# clutches 11785
# abyssmal 273
# chimp 10864
# alerted 1451
# graduation 26891
# greyson 27187
# yella 72086
# anthem 2457
# lha 36940
# baseball 4959
# madmen 38532
# auteurist 3918
# reine 52696
# garcin 25368
# illigal 31062
# platonic 48495
# larval 36176
# seam 56525
# bud 8294
# machines 38419
# cafe 8889
# decalogue 15594
# vexation 69162
# mur 42750
# vertido 69126
# plainer 48416
# shawshank 57498
# peopled 47354
# thoughtfulness 64652
# saint 55259
# mayne 39864
# referat 52460
# astonishment 3569
# shaffner 57275
# scouser 56307
# effeil 19676
# kilometre 34975
# ggooooodd 25887
# alienate 1508
# bama 4610
# limpid 37202
# moved 42443
# nonexistent 44177
# tographers 65196
# message 40689
# inflated 31991
# lachaise 35793
# simply 58405
# aparadektoi 2614
# longed 37687
# sponge 60440
# mechanised 40202
# malta 38888
# nella 43570
# renew 53005
# teau 63823
# realm 51980
# caille 8913
# yuppies 72321
# norman 44262
# farrellys 22473
# constraint 13132
# mroavich 42512
# pupsi 50772
# therese 64477
# desirous 16540
# popistasu 49023
# nykvist 44606
# mathematics 39706
# christen 11045
# kos 35451
# bounce 7442
# simultaneously 58423
# diner 17189
# winston 71192
# actioned 526
# qualifies 50999
# skinless 58701
# bros 8109
# rml 54178
# kagan 34291
# clunker 11772
# signoff 58275
# austro 3913
# shipments 57737
# lessness 36830
# supplies 62590
# edgy 19575
# pining 48220
# colossally 12170
# fullscreen 24894
# profiting 50086
# collectively 12086
# ishwar 33068
# presidents 49709
# twirl 66748
# musuraca 42872
# rotations 54650
# solicitude 59628
# megas 40324
# owen 46111
# timone 64992
# enduring 20465
# lonestar 37684
# busco 8635
# pertwee 47649
# wowzers 71676
# doggish 18137
# rincon 54020
# artyfartyrati 3312
# flare 23497
# outland 45728
# injects 32139
# objectionable 44686
# kerchief 34751
# amphlett 2000
# lofranco 37593
# multicolored 42644
# renovating 53030
# outings 45726
# stilwell 61300
# blatant 6513
# taxpayers 63744
# taxes 63733
# perovitch 47529
# sorbet 59815
# soda 59522
# wwwaaaaayyyyy 71839
# malice 38839
# naseeruddin 43234
# persepolis 47570
# exhaustion 21670
# jesuit 33676
# kampf 34369
# hilarious 29453
# mcbride 39908
# ghost 25913
# screecher 56359
# lookout 37741
# ninth 44012
# ferro 22899
# suffices 62231
# breathlessly 7767
# lugosi 38102
# camouflaged 9109
# kabbalism 34259
# darwinism 15320
# inarticulate 31498
# blackwood 6427
# improvisationally 31441
# maddona 38503
# alliende 1584
# pines 48209
# independent 31742
# earthbound 19412
# sodomy 59542
# dubois 18973
# nicoli 43873
# date 15345
# psychodramatic 50529
# banaras 4637
# sunbathing 62391
# resurrection 53497
# kitt 35144
# wolff 71391
# paintshop 46290
# psychotherapist 50550
# arye 3324
# caisse 8921
# simulacra 58412
# confedercy 12811
# escorting 21083
# current 14795
# tear 63802
# glob 26321
# onofrio 45198
# crete 14256
# diplomats 17250
# manat 38940
# victoriously 69245
# gazzaras 25567
# kyra 35734
# willian 71053
# mulletrific 42629
# discredit 17466
# podges 48734
# cantina 9263
# recesses 52147
# demotivated 16203
# frames 24393
# esthetes 21187
# ferox 22882
# register 52592
# drewitt 18786
# glaucoma 26246
# reactionary 51908
# ohtsji 45019
# considerate 13057
# lifes 37068
# dza 19349
# atm 3678
# standards 60863
# rachford 51269
# werewolf 70552
# gulpili 27635
# affords 962
# broadcasts 8014
# elogious 20032
# erroneous 21021
# grifters 27222
# numbed 44505
# homour 29964
# easterners 19439
# heiland 28965
# commerce 12339
# jiang 33727
# fam 22284
# lizie 37462
# gail 25139
# tearing 63807
# jorgen 33959
# piranha 48284
# swordfights 63050
# alphabet 1686
# mosely 42278
# declaim 15664
# bowfinger 7493
# borek 7318
# enslavement 20649
# copenhagen 13493
# sakamoto 55276
# con 12647
# dionyses 17238
# ostentatious 45619
# tributaries 66136
# welfare 70497
# maurren 39810
# yar 72001
# hypermacho 30774
# elise 19978
# prolo 50161
# zaphod 72399
# capriciousness 9345
# attained 3728
# insides 32274
# kitchenette 35133
# leaver 36522
# bender 5648
# mechanism 40203
# canoing 9244
# darkened 15261
# contessa 13241
# damiana 15099
# burgeoning 8536
# vehicular 68935
# shrieber 58010
# leone 36767
# prepaid 49635
# kim 34982
# outsize 45795
# vadar 68609
# smeaton 59148
# questionably 51107
# pasting 46868
# sighed 58235
# furry 24999
# teary 63813
# discriminate 17478
# revisions 53685
# usurer 68521
# bolla 7041
# docking 18040
# dominates 18229
# teetering 63892
# miz 41609
# shrines 58022
# leboeuf 36531
# amerindian 1912
# broadside 8024
# veddy 68900
# miltonesque 41125
# unwinds 68298
# tip 65047
# dolts 18208
# brummie 8180
# brightened 7911
# numberless 44509
# pauline 46997
# sergei 57046
# scales 55855
# chor 10993
# keena 34642
# hugger 30460
# armand 3102
# burly 8575
# skinniest 58706
# mayor 39866
# fortitude 24249
# bleakness 6541
# drab 18610
# nike 43952
# fumbles 24903
# disoriented 17660
# dinky 17210
# outstretched 45812
# smidgeon 59159
# powerbomb 49338
# arjun 3073
# spade 60004
# amu 2027
# dahlia 15015
# liberators 36980
# dalle 15064
# hiroshi 29578
# sledging 58879
# scorpions 56277
# hemlich 29078
# thenceforward 64425
# huntsman 30634
# mulligan 42633
# cartridges 9656
# compelling 12472
# tried 66161
# jewelery 33702
# machination 38414
# belt 5612
# cavanagh 9954
# zinger 72563
# obama 44653
# frequency 24619
# propel 50240
# shonen 57849
# gently 25741
# viagra 69180
# galactic 25169
# excelsior 21544
# pessimistic 47684
# allende 1569
# concorde 12727
# flickerino 23637
# sutra 62796
# repeat 53084
# modeling 41688
# laughingly 36302
# tuscosa 66653
# lenoir 36744
# smooshed 59214
# occaisionally 44810
# buoyant 8508
# iikes 31032
# reader 51920
# wierd 70963
# yeah 72052
# circumventing 11318
# asian 3392
# sumo 62378
# pulley 50660
# beak 5194
# edwards 19623
# unratable 68002
# castrated 9777
# guested 27537
# brutish 8215
# collateral 12074
# legendarily 36606
# euro 21287
# circuses 11320
# leguzaimo 36644
# gamine 25275
# mccormick 39947
# mindf 41166
# bluth 6827
# holier 29807
# rade 51303
# hairpin 27979
# plaudits 48502
# cortes 13710
# jarringly 33458
# glimcher 26285
# outspokenness 45807
# coital 12013
# serbians 57029
# lasts 36223
# fledged 23590
# caress 9455
# whammy 70642
# ardolino 2982
# burmese 8578
# spinsterhood 60317
# paleographic 46328
# zhen 72516
# lawyerly 36398
# twice 66730
# alike 1525
# digged 17073
# hardening 28342
# rousselot 54725
# xvichia 71901
# swing 62995
# mag 38567
# fulfilment 24885
# constantine 13111
# akcent 1307
# somewhat 59712
# ages 1061
# orgies 45487
# coolest 13448
# rocco 54287
# nonproportionally 44194
# memorably 40454
# embittered 20152
# orgasms 45483
# kikuno 34945
# insomniacs 32312
# definiately 15883
# comics 12276
# testimony 64257
# bryan 8221
# humourous 30575
# gulch 27622
# thoes 64599
# fbp 22645
# mishra 41434
# progressed 50120
# symbolism 63105
# slops 59018
# verbally 69034
# naysay 43373
# trimble 66188
# hathor 28575
# encroached 20395
# suffers 62228
# sideswiped 58196
# trueness 66382
# masonry 39566
# taranitar 63583
# dumpsters 19119
# magazine 38574
# technobabble 63845
# monetary 41878
# wistful 71262
# blacking 6394
# assailants 3439
# airforce 1241
# partanna 46748
# petting 47738
# sympathisers 63124
# beheading 5475
# shuttlecock 58099
# aortic 2604
# lipper 37317
# imc 31158
# hatchets 28556
# barmy 4856
# drizzling 18846
# bonet 7133
# parallelisms 46576
# helper 29053
# disinvite 17583
# prival 49922
# jenuet 33619
# doobie 18321
# teams 63797
# kristofferson 35571
# schmoeller 56099
# kukuanaland 35639
# writer 71765
# outfits 45715
# birdman 6260
# kgb 34824
# backhanded 4301
# elga 19946
# proprietor 50290
# finishers 23261
# hazardd 28692
# disjointedly 17585
# woar 71360
# lofts 37596
# leeves 36580
# gubbels 27508
# watchers 70204
# corncobs 13595
# gwoemul 27785
# whine 70740
# dimanche 17149
# basinger 4998
# countoo 13872
# slimmed 58950
# suitable 62284
# age 1047
# unveiled 68266
# weakest 70317
# altar 1712
# cocoon 11901
# abigil 119
# avanti 4008
# nullifying 44499
# brings 7949
# spite 60350
# dimensionality 17156
# automation 3971
# erroneously 21022
# unsex 68123
# flubber 23802
# manderley 38970
# khali 34832
# cosimo 13732
# unlocked 67838
# kabob 34265
# deewaar 15788
# brennen 7813
# diagonal 16885
# boulting 7440
# constructively 13146
# dupres 19189
# odder 44886
# suppliers 62589
# grill 27227
# kirkendall 35095
# drizzled 18845
# lisping 37350
# unconstitutional 67217
# foist 23913
# lea 36447
# woodeness 71464
# snoozing 59392
# fleabag 23582
# danson 15208
# coincides 12008
# pharmaceutical 47793
# incurable 31703
# regions 52590
# cured 14769
# himalayas 29497
# easthamptom 19441
# civilised 11353
# viennese 69289
# loeb 37583
# diggers 17075
# barreled 4892
# tranquillo 65783
# fandom 22334
# schmoes 56100
# clearest 11529
# derricks 16451
# broadened 8016
# moralist 42117
# ambersons 1842
# dugdale 19039
# avonlea 4073
# scalp 55865
# bodysuckers 6936
# alligator 1586
# martains 39450
# suzhou 62814
# schnitz 56112
# scheduling 56023
# bunged 8483
# sideburns 58174
# sweetly 62947
# johansson 33862
# underlie 67329
# whey 70714
# clyve 11796
# howls 30364
# mpk 42504
# longoria 37707
# deary 15510
# buttons 8736
# exposing 21878
# diametrically 16910
# popsicle 49038
# obsessively 44767
# culled 14685
# unemotional 67492
# sommerset 59719
# trude 66367
# screechy 56362
# troubling 66327
# snidely 59332
# alterego 1721
# gruanted 27423
# lends 36716
# hair 27961
# onhand 45184
# loesing 37586
# buenos 8323
# wiseass 71230
# spunk 60584
# tours 65588
# sardine 55605
# polemical 48829
# uninfected 67724
# cripplingly 14325
# denny 16255
# frelling 24597
# vessel 69139
# insted 32350
# pageant 46246
# konvitz 35410
# scope 56252
# tepos 64131
# geopolitics 25775
# kollek 35376
# seda 56649
# malayalam 38806
# defilement 15866
# whiners 70743
# fernandel 22874
# vacationing 68588
# partioned 46785
# gardeners 25375
# chio 10887
# skewered 58661
# bingham 6208
# samundar 55429
# bloodbank 6676
# outerspace 45711
# vanne 68787
# moriarity 42175
# haas 27837
# kimmell 34993
# narrators 43213
# fury 25013
# lowlights 37992
# fruitcake 24798
# sigur 58286
# firesign 23324
# notti 44373
# mechas 40207
# wranglers 71691
# aaa 0
# duh 19043
# kirschner 35102
# tuckwiller 66493
# entrepreneurial 20762
# ryunosuke 55073
# deel 15761
# youngish 72244
# scene 55979
# cornish 13619
# manjayegi 39072
# rafael 51348
# gopher 26696
# outriders 45777
# sunniest 62420
# fathoming 22565
# purgation 50791
# jacksons 33263
# beban 5289
# tkom 65126
# rotting 54675
# phrase 47970
# maddeningly 38496
# reynold 53769
# mortars 42246
# adhesive 667
# bryanston 8223
# particular 46772
# constant 13110
# semprinni 56858
# explication 21825
# whately 70651
# courtiers 13915
# erasmus 20942
# ordeal 45426
# rusticism 55002
# reassurance 52038
# naushad 43337
# gaggle 25122
# scrat 56337
# ambulance 1866
# detonated 16697
# popularly 49053
# extramarital 21979
# extortion 21969
# cass 9722
# engrosses 20538
# banjoes 4685
# mady 38551
# pian 48007
# bricklayers 7862
# wachowski 69810
# palpatine 46376
# spiderbabe 60260
# chia 10765
# espousing 21136
# tuareg 66476
# reassembled 52029
# seeker 56691
# bernal 5802
# remained 52880
# creely 14219
# euguene 21266
# broadest 8019
# pastors 46873
# gourds 26799
# encyclopedic 20410
# looses 37788
# leaven 36519
# maltz 38897
# stir 61341
# windfall 71119
# spearmint 60113
# robinson 54260
# jutta 34227
# aphrodite 2643
# christening 11047
# season 56565
# huns 30623
# breakthrough 7748
# poundingly 49310
# unlocks 67840
# frasier 24477
# currie 14800
# nadji 43042
# previn 49804
# seamed 56528
# bukater 8380
# cooperating 13469
# arthur 3260
# kicky 34897
# nabiki 43005
# dictator 16980
# games 25269
# ornaments 45544
# devalued 16732
# blush 6818
# nelly 43574
# pothead 49275
# caprio 9348
# busted 8676
# scalped 55866
# seymour 57226
# disregards 17746
# dingo 17201
# practising 49383
# formulates 24211
# moviedom 42457
# narrations 43208
# briggs 7907
# bosoms 7381
# allen 1568
# twelfth 66719
# montanas 41989
# workshop 71583
# marlee 39373
# poupard 49313
# tetanus 64266
# yakitate 71945
# humpdorama 30579
# gnarly 26398
# offence 44934
# easiness 19432
# dispiritedness 17699
# oaf 44629
# recon 52227
# worsen 71621
# economises 19537
# ceremony 10161
# cambodian 9061
# atlante 3665
# nonactor 44161
# computer 12628
# revisit 53686
# zombied 72619
# joki 33908
# preppie 49651
# lollo 37650
# mandel 38965
# abortionists 165
# mushy 42823
# bonsais 7158
# incumbent 31702
# grandness 26965
# vomitum 69703
# alabama 1342
# rebelling 52066
# feuds 22962
# ledger 36557
# sought 59879
# supernovas 62525
# keester 34657
# musashi 42792
# caracortada 9391
# precipitous 49475
# macgyver 38396
# spacecamp 59978
# timey 64981
# extents 21936
# masons 39567
# goodbye 26621
# schieder 56045
# jelousy 33596
# unfortenately 67607
# ineffectiveness 31872
# summarily 62345
# swingers 62999
# maximals 39828
# refundable 52533
# tenderer 64056
# fraulein 24499
# oft 44985
# elk 19998
# sudetenland 62204
# slaughtering 58838
# dagwood 15012
# unavailing 67073
# barracks 4882
# deterrance 16677
# ghunghroo 25938
# moonlit 42061
# nudity 44474
# bumblers 8456
# clocked 11669
# charis 10441
# keeper 34650
# aintry 1225
# batteries 5092
# cousin 13926
# bartend 4931
# shrubs 58040
# kingmaker 35037
# waddling 69832
# geist 25615
# crabby 14013
# copeland 13492
# spotlighted 60503
# artifices 3279
# volita 69659
# chatrooms 10525
# consult 13156
# landa 36015
# val 68640
# moskve 42290
# intimate 32701
# tegan 63902
# eyelashes 22047
# desks 16545
# implemented 31336
# unmannered 67856
# tenchu 64048
# claustrophobic 11488
# outside 45791
# grandstand 26971
# onyulo 45219
# completes 12531
# skimping 58689
# dogging 18136
# narcoleptic 43194
# ekin 19827
# carjacking 9490
# depreciative 16376
# granite 26974
# intimacy 32700
# warble 70051
# unnerved 67906
# chorines 11011
# shaffer 57274
# mangy 39013
# mandark 38959
# sciences 56211
# courted 13909
# biased 6037
# bilal 6138
# throwaways 64737
# songwriter 59749
# grab 26846
# stenographer 61153
# barbirino 4786
# double 18486
# shes 57638
# wader 69835
# lensing 36752
# dissected 17786
# plebes 48579
# formulmatic 24215
# unreleasable 68044
# pacman 46202
# rectified 52296
# meg 40301
# chihuahuas 10813
# underplays 67359
# catcalls 9825
# footages 24004
# alow 1679
# brady 7567
# metaphorically 40749
# sopping 59808
# cinenephile 11264
# acquiring 492
# horned 30136
# mural 42751
# adriana 789
# reinvigorated 52725
# bone 7121
# confrontation 12874
# glittering 26307
# cherry 10708
# waterside 70241
# geometrical 25771
# undertitles 67404
# stylishly 61932
# restaurateur 53447
# nuts 44572
# vanlint 68785
# hybrids 30729
# soni 59753
# harpies 28441
# dts 18951
# sausage 55759
# irreverently 33013
# jeong 33621
# insectoid 32251
# gape 25336
# deceased 15612
# tolokonnikov 65253
# goldfield 26543
# fetishwear 22950
# mongering 41890
# psychotherapists 50551
# merhi 40610
# trams 65768
# dramas 18657
# juggling 34094
# cambell 9059
# valalola 68642
# formidable 24198
# enid 20555
# urmitz 68462
# zen 72481
# tomboyish 65272
# hungrier 30611
# ewwww 21477
# dispelled 17683
# cinch 11210
# eggotistical 19723
# gaiday 25136
# verdant 69045
# capas 9290
# catholique 9885
# dumps 19117
# newspeak 43762
# bronchitis 8071
# weisz 70484
# goriest 26732
# stylish 61931
# bikumatre 6136
# injustice 32150
# loewe 37589
# parading 46554
# sheedy 57528
# vignettes 69323
# biangle 6032
# baytes 5151
# unhappier 67665
# trombones 66285
# schnitzler 56113
# remaking 52885
# textbook 64294
# jalal 33336
# observations 44752
# clarksburg 11434
# patina 46930
# advert 849
# navel 43356
# denial 16226
# klenhard 35192
# bludgeons 6772
# tearjerking 63810
# eet 19659
# togther 65198
# priggish 49847
# griffths 27218
# appologize 2788
# suberb 61979
# pasty 46879
# weber 70369
# sami 55401
# stimulations 61308
# smallpox 59111
# minced 41153
# begley 5447
# patronizes 46972
# noughts 44382
# bake 4461
# iyer 33208
# dogs 18151
# commodified 12383
# drilled 18811
# refugee 52529
# urinates 68454
# silvestri 58347
# sticky 61258
# germany 25821
# insofar 32306
# roast 54221
# burkhardt 8563
# dedicates 15735
# fraternity 24484
# bemoaned 5630
# jenkins 33604
# prattle 49426
# slalom 58790
# ouedraogo 45662
# bakeries 4465
# expectable 21752
# maruja 39487
# sizable 58594
# drainage 18645
# these 64488
# uccide 66863
# denier 16230
# specialized 60127
# karenina 34442
# poultry 49302
# inimitable 32121
# takingly 63387
# interconnected 32516
# troupe 66337
# anayways 2106
# broadcaster 8011
# avatars 4014
# mesmeric 40673
# thickies 64521
# retaliated 53514
# mamooth 38923
# crazed 14152
# crayons 14150
# beatings 5247
# apparition 2710
# babylon 4248
# speedball 60187
# hayseeds 28683
# esquire 21143
# stratified 61594
# highwater 29429
# marci 39219
# abstract 237
# tare 63597
# frenzy 24616
# mish 41419
# starlift 60944
# cease 10010
# pliable 48599
# kotm 35481
# quatermain 51054
# enki 20573
# deviates 16773
# grunner 27461
# globe 26329
# dissertations 17802
# mcgovernisms 40008
# womanises 71414
# lampe 35981
# crowded 14486
# meanspirited 40161
# umptieth 66994
# fabinyi 22075
# atticus 3758
# sated 55676
# peeping 47207
# humanness 30525
# bim 6190
# abolish 140
# gunsmoke 27706
# kaun 34574
# tester 64245
# wraiths 71687
# recycling 52319
# circumcision 11305
# badmen 4382
# motherland 42326
# relaying 52797
# channelling 10351
# rycart 55045
# vinessa 69415
# anan 2083
# reasserts 52034
# anemic 2195
# fixed 23410
# xyx 71912
# bikay 6125
# through 64727
# divya 17984
# sponsorship 60449
# bowl 7496
# nabs 43014
# denim 16240
# nuked 44490
# complacent 12508
# upfront 68340
# hike 29446
# rupture 54964
# pierrot 48109
# regaining 52552
# vicki 69222
# hanfstaengel 28220
# cathay 9874
# practised 49381
# fairfaix 22192
# deviated 16772
# piven 48357
# hagerthy 27915
# unremitting 68055
# dupuis 19191
# wises 71244
# abstraction 239
# concentrates 12674
# chitre 10915
# shapes 57402
# disease 17502
# underestimated 67305
# destitute 16613
# misguidedly 41416
# larder 36136
# maurizio 39808
# facade 22092
# ley 36933
# wireframe 71216
# prey 49809
# natascha 43259
# snoring 59397
# wonderment 71440
# drapes 18687
# designates 16525
# strap 61574
# paintbrush 46282
# formulas 24208
# derision 16422
# arlook 3093
# didactic 16992
# ministering 41238
# coservationist 13728
# would 71650
# hadled 27893
# stupified 61899
# darbar 15234
# dobermann 18029
# clockwork 11675
# screeds 56364
# singled 58459
# maeder 38554
# light 37088
# haired 27975
# dunce 19127
# deardon 15503
# olphelia 45108
# unfulfilled 67626
# intl 32711
# digital 17088
# strangles 61568
# treasureable 66005
# caugh 9922
# misdemeanors 41381
# leire 36663
# merge 40606
# barca 4794
# roadmovie 54196
# langella 36067
# scatalogical 55945
# schooling 56145
# lions 37303
# khrysikou 34867
# bering 5780
# mickie 40888
# reverberate 53640
# protagoness 50341
# deadset 15475
# lip 37310
# sugimoto 62270
# apologise 2669
# aveu 4044
# rhinier 53802
# resolutive 53372
# irritatingly 33028
# moosic 42084
# kabhi 34261
# inventor 32814
# panes 46438
# resolves 53376
# ziyi 72593
# baddie 4357
# after 1014
# quibbles 51123
# bladck 6431
# aleination 1439
# luxurious 38265
# peque 47381
# food 23982
# different 17035
# ninotchka 44009
# carnet 9534
# herzegovina 29264
# ziploc 72573
# striped 61717
# hildebrand 29463
# riffing 53935
# strived 61728
# alysons 1781
# sabretooth 55112
# racing 51273
# grippingly 27280
# cody 11926
# enticing 20722
# switchblade 63023
# tipper 65051
# suitcases 62287
# dissed 17791
# mcconnahay 39942
# gravina 27058
# martyrdom 39483
# gummo 27647
# eery 19656
# squandering 60624
# dishwashers 17561
# cubs 14648
# helte 29067
# contradiction 13301
# hissy 29598
# invictus 32850
# susco 62753
# rattler 51776
# seduction 56672
# minna 41249
# jain 33325
# offices 44959
# talentwise 63406
# harried 28458
# moon 42050
# kiesche 34935
# underacts 67281
# airlift 1251
# groin 27328
# unopened 67922
# travers 65973
# punctures 50718
# rationalized 51760
# fascistoid 22504
# chamberlin 10288
# timpani 64997
# realized 51972
# imovie 31238
# harm 28409
# snowman 59419
# sympathise 63121
# koster 35467
# zerelda 72497
# panoramas 46467
# demonisation 16176
# treads 66000
# masterfully 39617
# repertoire 53104
# hsd 30402
# barbados 4758
# lackadaisical 35802
# catchphrase 9834
# fifth 23062
# hankshaw 28247
# depardeu 16310
# volunteered 69689
# petto 47740
# assist 3512
# runnin 54948
# deforest 15909
# stubly 61817
# trapero 65917
# otto 45658
# downwind 18590
# ogend 44992
# typography 66819
# manos 39114
# sell 56804
# informing 32031
# oughta 45664
# entirely 20726
# rottweiler 54677
# tags 63317
# gwot 27786
# whitechapel 70798
# contention 13235
# levieva 36900
# murry 42785
# zippier 72577
# resentful 53296
# harlow 28407
# incidences 31565
# mcswain 40108
# upsurge 68402
# bookish 7212
# worried 71611
# tian 64832
# friar 24655
# poptart 49041
# fenner 22838
# wearing 70338
# visitations 69524
# solimeno 59641
# baddy 4361
# punishment 50731
# rides 53899
# mar 39181
# hepo 29145
# org 45454
# kewl 34801
# complement 12520
# unraveled 68006
# bapu 4741
# kashmir 34497
# higginson 29393
# headed 28725
# spindles 60296
# barbapapa 4759
# kotero 35477
# eluded 20068
# pith 48332
# dalens 15054
# unwilling 68293
# befittingly 5412
# bippity 6253
# perspectives 47621
# fave 22601
# handicaps 28180
# phenomonauts 47824
# singelton 58451
# revue 53730
# avoidable 4065
# wholehearted 70855
# regarding 52563
# hauteur 28620
# wager 69851
# trickiest 66148
# furls 24985
# urn 68463
# ardh 2980
# phoenix 47920
# used 68488
# betamax 5900
# bartok 4944
# rival 54134
# edgiest 19572
# oxide 46127
# vulkan 69777
# quetin 51116
# ashraf 3382
# numers 44524
# anchorwoman 2125
# boosts 7264
# renegade 53004
# undergraduate 67320
# kurasowa 35671
# triers 66163
# thousand 64660
# sprinting 60565
# supersedes 62534
# fabrications 22086
# nicest 43821
# scoping 56255
# conductor 12792
# swarms 62874
# zeffirelli 72458
# talkshow 63429
# mcvay 40111
# mvp 42923
# unloveable 67844
# arcs 2970
# ched 10600
# meanings 40157
# witticism 71326
# newed 43726
# rohtenburg 54395
# scabby 55844
# lonely 37679
# calcium 8947
# fidelity 23025
# zach 72351
# paulista 46998
# penneys 47316
# eluding 20070
# jist 33780
# stettner 61225
# buzzell 8759
# moonchild 42054
# noe 44105
# emancipated 20096
# rightful 53971
# casel 9689
# comedies 12248
# victimizer 69231
# slevin 58914
# hofd 29742
# lungs 38185
# prodding 50028
# hing 29528
# contaminates 13200
# twitty 66768
# radiologist 51332
# bids 6071
# rachel 51266
# stymieing 61947
# agnes 1104
# kireihana 35087
# ade 640
# opprobrious 45344
# stamper 60850
# jug 34087
# unprofessionals 67983
# ladd 35827
# iannaccone 30845
# winters 71200
# mongol 41894
# affiliation 937
# british 7984
# emblazered 20153
# moped 42094
# americanised 1901
# storefront 61460
# gyaos 27795
# endowment 20453
# editorial 19593
# josten 33988
# assael 3437
# tia 64830
# phillipines 47876
# whitlow 70828
# unpleasantness 67952
# enslin 20652
# welsh 70519
# jee 33551
# cluny 11780
# skateboards 58619
# obsessing 44763
# casino 9711
# millennial 41093
# bogart 6954
# implode 31349
# kiyomasa 35157
# cpl 14007
# issues 33123
# mails 38698
# snare 59282
# mumabi 42681
# comeuppance 12263
# amayao 1826
# eubanks 21259
# subliminally 62008
# disproportionate 17725
# theieves 64395
# deploy 16347
# active 540
# grinder 27255
# turgid 66599
# angelos 2228
# zering 72499
# hannigan 28258
# kalashnikov 34328
# eliminations 19968
# plympton 48702
# syndrome 63174
# absolution 219
# budd 8298
# calibration 8981
# nba 43382
# hostile 30248
# dor 18398
# retiring 53551
# unfindable 67572
# willowbrook 71067
# heche 28873
# unsaid 68084
# thalberg 64323
# tarrantino 63629
# descriptive 16490
# arduous 2986
# hes 29268
# wand 70010
# lotte 37864
# cotta 13786
# masquerades 39572
# amitabhs 1947
# scowls 56314
# fleck 23587
# fooled 23989
# student 61827
# contempt 13222
# scanner 55890
# pumpkin 50695
# lyoko 38316
# blurt 6815
# cheapness 10573
# funnily 24961
# lame 35957
# tamahori 63456
# reins 52706
# obeys 44673
# tooling 65351
# puce 50599
# ethnocentrism 21245
# militaristic 41064
# laraine 36129
# boobless 7175
# imaginaire 31122
# unninja 67910
# stoichastic 61389
# derriere 16453
# results 53483
# francophiles 24431
# fairfax 22193
# tajmahal 63355
# held 28991
# somtimes 59729
# unrecognizable 68028
# jaime 33323
# ditching 17906
# awfull 4121
# mahatama 38662
# demential 16131
# segregated 56733
# denote 16260
# gymakta 27800
# coverage 13944
# nandini 43141
# apology 2678
# brett 7829
# plane 48429
# beats 5259
# ariell 3046
# raju 51478
# relearn 52799
# dialoge 16901
# nyt 44624
# accentuated 301
# logon 37619
# karizma 34452
# nubb 44457
# ecstatic 19546
# yer 72112
# portfolios 49122
# housecleaning 30309
# stephani 61169
# unwrapping 68307
# horatio 30112
# yaks 71949
# gershwin 25843
# lepers 36792
# godawful 26449
# deem 15763
# debatable 15539
# safari 55195
# firebird 23296
# advocate 875
# script 56412
# bowdlerised 7483
# intellivision 32459
# aracnophobia 2887
# eva 21309
# hornburg 30132
# dip 17242
# heavier 28857
# dosages 18457
# fatherhood 22556
# undermines 67342
# davidtz 15384
# recoup 52269
# dozed 18601
# triggers 66176
# itfa 33159
# thorough 64633
# fleischer 23604
# hauntingly 28611
# conversational 13380
# staffs 60753
# pok 48799
# bicarbonate 6049
# bragging 7577
# cornel 13600
# logically 37611
# kananga 34374
# hop 30078
# jafri 33301
# sequestered 57006
# doughton 18516
# bedtime 5354
# higher 29400
# descriptions 16489
# nourishes 44385
# commemorating 12309
# quarantined 51023
# macadam 38350
# numerical 44519
# reflects 52488
# lei 36649
# mange 38999
# sev 57150
# kingdome 35033
# choreographed 11000
# dooper 18355
# interchangeably 32511
# harem 28374
# vandicholai 68766
# teensy 63883
# cellulose 10086
# minute 41282
# crepe 14247
# guileless 27573
# womanize 71416
# litening 37378
# countering 13855
# stating 61002
# conde 12740
# lucrencia 38069
# kazaki 34601
# narrow 43214
# mbbs 39891
# setna 57122
# croasdell 14387
# shiven 57783
# viertel 69293
# lodi 37580
# fisticuff 23377
# dingos 17203
# friggen 24693
# satana 55665
# drum 18916
# mottos 42384
# gypo 27812
# bulldosers 8408
# klutziness 35226
# unamusing 67039
# hinkley 29534
# anoying 2415
# taht 63325
# propels 50246
# freaks 24524
# kamala 34348
# acin 449
# drohkaal 18848
# blithering 6627
# ran 51569
# canadian 9155
# underexplained 67309
# discourses 17457
# weep 70414
# speeches 60183
# nytimes 44625
# poolman 48997
# dylan 19318
# deletes 16019
# beds 5349
# feinstein 22753
# audience 3817
# opacity 45260
# envelop 20785
# annis 2362
# courses 13905
# naughton 43324
# adultry 814
# figures 23093
# amalgamated 1791
# molecular 41799
# chevette 10745
# gurns 27725
# mcmichael 40072
# widdoes 70931
# usherette 68505
# nickeloden 43839
# hackneyed 27875
# trapeze 65918
# jonh 33940
# himalaya 29495
# frenchman 24604
# jeyaraj 33712
# hallways 28069
# juscar 34200
# blais 6449
# parvarish 46805
# lejanos 36677
# application 2772
# rfk 53773
# pittiful 48345
# reasonbaly 52024
# milkman 41075
# settings 57131
# seann 56541
# jonas 33925
# cuts 14885
# aiken 1196
# listenable 37355
# gilmore 26057
# motorcross 42362
# mutti 42909
# sebastians 56591
# comatose 12208
# rectangular 52295
# local 37526
# spank 60030
# plateaus 48479
# sulu 62331
# tosca 65496
# speredakos 60231
# conceived 12668
# demanded 16113
# woorter 71527
# bringer 7946
# guinn 27600
# zaara 72340
# recogniton 52196
# cartons 9643
# beaus 5269
# falsehood 22262
# insanely 32238
# thirteenth 64583
# quitting 51197
# oblivious 44717
# brewsters 7842
# million 41107
# feminine 22811
# livening 37434
# competently 12491
# kurasawa 35670
# immortal 31220
# fanfilm 22340
# amazons 1837
# plater 48482
# shakur 57328
# bagging 4410
# tug 66507
# youth 72262
# menstruating 40533
# pussycat 50875
# afl 984
# stiltedness 61298
# threshold 64694
# forster 24231
# exiting 21712
# endorsement 20447
# anthropomorphised 2471
# shawls 57495
# radioing 51330
# kirk 35094
# slicked 58923
# windmill 71125
# missolonghi 41516
# zabalza 72342
# fingertips 23251
# thereof 64473
# internship 32609
# cursory 14811
# chakotay 10248
# kowalski 35495
# shead 57511
# aldo 1425
# drummers 18921
# vocalize 69617
# elegiac 19915
# beckett 5305
# tastelessness 63672
# whatsoever 70663
# chronic 11088
# koppikar 35424
# explorers 21855
# paramore 46593
# unessential 67521
# tomato 65264
# strawberry 61607
# respectable 53401
# transmit 65862
# gregorini 27157
# closure 11708
# haliburton 28021
# insubordination 32397
# selflessly 56798
# overproduced 45999
# abundantly 255
# selectively 56788
# related 52773
# soong 59773
# cartoonist 9651
# speakers 60101
# macabre 38348
# motorcyclist 42366
# woamn 71359
# skits 58728
# mili 41054
# femininity 22812
# coldly 12038
# detectors 16656
# benign 5687
# newsflash 43753
# healthily 28776
# toyo 65643
# charisma 10443
# gordious 26705
# panache 46402
# musicians 42831
# stanislav 60883
# sallu 55335
# organs 45479
# crackers 14023
# clifford 11601
# market 39347
# entities 20729
# locals 37533
# existience 21706
# peregrinations 47419
# pat 46880
# soavi 59465
# macarthur 38361
# coixet 12015
# magots 38641
# unpolite 67958
# garloupis 25402
# lice 37003
# wilkie 71030
# flatley 23526
# superlguing 62505
# advancement 820
# prominence 50176
# scattered 55956
# bonesetter 7131
# mariel 39284
# suares 61953
# gainsay 25156
# altered 1720
# pscychological 50474
# bartram 4947
# crated 14125
# corlan 13584
# heartaches 28802
# lapsed 36121
# hormonal 30125
# mancuso 38956
# herg 29187
# excavations 21525
# ucsb 66869
# producer 50038
# vertical 69124
# tatters 63695
# devastatingly 16739
# plato 48494
# partnering 46794
# chomiak 10963
# fffc 22977
# isabella 33043
# legitimately 36630
# seon 56964
# barrack 4881
# bashes 4979
# rienforcation 53925
# metalflake 40727
# captian 9361
# resoundness 53391
# immobile 31212
# kinkade 35049
# thursdays 64819
# thorwald 64642
# undeniably 67273
# document 18066
# advancing 823
# busting 8684
# ides 30935
# spain 60013
# ostfront 45624
# ole 45087
# brochures 8032
# outgrew 45719
# resides 53334
# paneling 46435
# massironi 39599
# urinating 68455
# intuitive 32776
# motives 42351
# kiri 35089
# insert 32266
# filler 23120
# dweezil 19289
# greensward 27139
# tearoom 63811
# bolkonsky 7039
# further 25003
# antirust 2515
# dinasty 17187
# mommie 41844
# simulations 58420
# derangement 16408
# athinodoros 3647
# foods 23984
# forebodings 24070
# comprised 12609
# carerra 9453
# fascism 22501
# phd 47806
# sperm 60232
# duffle 19031
# neighborhood 43534
# baleful 4522
# canoes 9243
# rear 52009
# exotic 21729
# comprehensions 12601
# wolfstein 71397
# fiedler 23034
# peeks 47197
# rad 51293
# milf 41049
# pollinating 48889
# peebles 47190
# crew 14263
# upstages 68394
# clone 11685
# plot 48623
# unscrewed 68099
# solid 59629
# colwell 12201
# tan 63500
# unmanaged 67852
# polarizes 48819
# jeane 33532
# stronghold 61763
# confidentially 12833
# bahal 4426
# affiliate 935
# gigolo 26013
# freakout 24523
# bemused 5633
# pomegranate 48933
# astor 3570
# baumer 5125
# nags 43061
# davis 15388
# casablanca 9677
# roundly 54712
# movements 42449
# valued 68711
# sumire 62341
# coughs 13802
# suwkowa 62805
# excitedly 21572
# lofaso 37591
# emmanuel 20233
# groovin 27344
# denchs 16218
# continuously 13273
# phoenicia 47917
# rusted 55000
# qaulen 50955
# turds 66596
# noland 44133
# regs 52616
# vivian 69585
# cheese 10633
# thanksgivings 64344
# accomplices 354
# performances 47448
# groundwork 27388
# perished 47483
# desando 16462
# phenoms 47825
# airmen 1259
# crewmen 14269
# artwork 3309
# farted 22481
# investigates 32833
# alarmist 1362
# unambiguous 67034
# ricca 53846
# superegos 62468
# ranging 51605
# whinging 70747
# bocaccio 6897
# unnamed 67895
# wildlife 71008
# traveler 65962
# laroche 36157
# manicness 39039
# aragon 2890
# smog 59193
# schoolmates 56151
# baron 4874
# landowners 36044
# medals 40220
# bereavement 5747
# wana 70009
# lar 36127
# discombobulated 17419
# parental 46649
# walsh 69988
# dinnerladies 17212
# kasey 34495
# peruvian 47655
# stifled 61274
# ingwasted 32085
# medicating 40245
# fillers 23121
# convalescing 13357
# boal 6846
# zhu 72524
# shortchanges 57894
# agless 1102
# hahk 27936
# slightyly 58943
# tickled 64856
# traversed 65975
# seaman 56526
# deth 16687
# committing 12380
# daybreak 15413
# plotless 48625
# emissary 20225
# perving 47674
# entrenches 20759
# bohumil 6993
# sciusci 56227
# arise 3054
# slabs 58771
# timberflake 64944
# perrine 47555
# agamemnon 1042
# crisp 14331
# noonann 44219
# satisfies 55709
# gutted 27754
# venison 68995
# forgets 24148
# indisputably 31810
# apanowicz 2613
# tizzy 65123
# unpopular 67960
# embarrassment 20130
# thornton 64630
# demotion 16202
# snooty 59387
# antidepressants 2494
# luxembourg 38259
# titillating 65103
# dumberer 19086
# wizs 71342
# loudmouth 37878
# chives 10920
# nikolayev 43967
# trojans 66277
# grungy 27460
# jbl 33521
# circuit 11292
# grunge 27459
# pallance 46350
# macbeal 38366
# flaw 23570
# revisitation 53687
# udder 66871
# coraline 13541
# ultimate 66948
# flashforwards 23510
# trully 66392
# correlating 13668
# sprays 60533
# shrieking 58014
# nearby 43405
# panged 46442
# resuming 53488
# amis 1939
# crestfallen 14254
# threesome 64691
# puchase 50601
# hagerty 27916
# yoshi 72214
# weeklies 70402
# trounced 66334
# quashed 51049
# tyres 66835
# welders 70493
# famines 22305
# forme 24193
# samoa 55408
# subjectively 61992
# plucked 48645
# cadaver 8862
# rewrite 53755
# firekeep 23314
# minnesotan 41254
# seond 56965
# consolidate 13084
# alabaster 1343
# exhibitions 21680
# isobel 33096
# dowry 18592
# robbin 54236
# neatly 43419
# cassady 9723
# durians 19210
# becomes 5320
# winterich 71198
# glasgow 26238
# connory 12986
# goofus 26664
# sparkles 60052
# larissa 36148
# domestication 18222
# era 20926
# snagged 59259
# overconfidence 45879
# fopish 24032
# repossessing 53170
# exemplified 21646
# julias 34124
# cringeworthy 14311
# mickey 40886
# pixely 48364
# kph 35505
# rombero 54466
# dares 15246
# philips 47866
# masanori 39527
# preconception 49490
# standish 60869
# wars 70133
# stipulates 61339
# emptour 20316
# stanwyk 60894
# molt 41827
# paedophile 46231
# borowczyks 7354
# benson 5717
# opinions 45305
# guesswork 27535
# spider 60259
# callus 9026
# everyone 21396
# stoked 61392
# amin 1936
# caron 9562
# ziva 72591
# boggins 6971
# plotty 48632
# hemorrhaging 29089
# giacchino 25942
# docudrama 18064
# generalised 25654
# hugh 30467
# franic 24435
# approve 2832
# glassy 26244
# ascends 3341
# backwood 4335
# seconds 56610
# resignation 53340
# yam 71959
# characters 10416
# hangouts 28234
# austeniana 3892
# scuttling 56492
# discriminated 17479
# dandy 15156
# programming 50117
# michaelango 40859
# leopold 36784
# accused 402
# sarajevo 55586
# evan 21325
# rounder 54708
# petticoat 47734
# coutland 13934
# ref 52458
# shirely 57752
# buttafuoco 8714
# automatons 3973
# souls 59892
# marvelously 39500
# hpd 30382
# barnabus 4858
# mirrorless 41322
# cruises 14541
# dictatorships 16984
# quizzically 51209
# throbbed 64716
# verged 69058
# interchanges 32513
# dumbbells 19082
# rudeness 54845
# impalings 31257
# clint 11641
# balancing 4499
# thirdspace 64576
# southwest 59946
# evilness 21428
# jiving 33787
# bakshis 4480
# dondaro 18275
# lucinenne 38053
# harald 28305
# afterwords 1034
# laura 36331
# unlockables 67837
# gales 25183
# boffing 6949
# switch 63022
# sousa 59927
# stunts 61879
# townhouse 65619
# ineptness 31882
# popeil 49018
# bless 6575
# howard 30344
# reverted 53662
# artistic 3294
# mcnalley 40082
# lonny 37726
# tattered 63694
# caballe 8816
# bergeres 5768
# contrast 13313
# breakable 7730
# antonioni 2539
# conserve 13050
# pinet 48210
# ens 20637
# screwer 56391
# astrotech 3603
# philo 47883
# diverts 17946
# extensively 21933
# treatise 66016
# kiddie 34902
# gardens 25378
# dissapointing 17773
# showmanship 57979
# copycat 13527
# bogdanoviches 6960
# shtoop 58051
# roadies 54194
# artel 3243
# submit 62023
# callarn 9006
# tending 64064
# gainsbrough 25160
# matthews 39762
# bruneau 8185
# cache 8844
# wyeth 71846
# shya 58108
# gillman 26054
# sugarman 62251
# backett 4294
# camerons 9086
# scopophilia 56256
# chillingly 10848
# irritates 33026
# blimey 6594
# fends 22833
# luck 38056
# dubbing 18963
# scarman 55933
# comings 12282
# leonor 36777
# vernon 69095
# kierlaw 34932
# kaminsky 34362
# saboteur 55105
# insightfulness 32280
# exploitational 21836
# eleanora 19872
# achievers 433
# grave 27042
# scren 56383
# zfl 72512
# smugglers 59238
# silo 58324
# geewiz 25601
# releasing 52803
# guddi 27515
# ulu 66961
# splendour 60392
# latrine 36267
# chaffing 10220
# vies 69294
# voigt 69648
# clipping 11650
# henchmen 29100
# spaceballs 59977
# babbling 4223
# orpington 45558
# viccaro 69203
# wans 70037
# stained 60784
# lancaster 36003
# histrionic 29612
# sydney 63077
# excepts 21553
# villain 69361
# brick 7858
# debris 15564
# dwindled 19302
# aero 885
# maraglia 39186
# going 26514
# fistful 23376
# joker 33902
# pontificator 48970
# blainsworth 6446
# booked 7202
# phoenixville 47922
# melies 40389
# heorine 29140
# ...
# windblown 71113
# dragonheart 18636
# meaning 40148
# watermelons 70237
# islander 33082
# aged 1048
# alos 1672
# lipsticked 37323
# zeder 72451
# smurfs 59245
# greytack 27190
# hare 28371
# antonis 2541
# recaptured 52113
# russians 54992
# transplants 65885
# abolitionists 144
# pilippinos 48157
# orr 45559
# devourer 16825
# decrease 15718
# billionaire 6175
# tipped 65050
# enumerated 20776
# syndication 63173
# elicits 19956
# narrate 43203
# fleas 23585
# gandhis 25290
# lolly 37653
# lankford 36090
# cardinal 9423
# repels 53095
# inexistent 31905
# dukesofhazzard 19056
# hilcox 29461
# overdramatized 45898
# darkwolf 15283
# mirna 41316
# racquel 51291
# hindersome 29515
# cutish 14878
# ohmigod 45013
# breathed 7762
# manichean 39037
# polynesian 48925
# hurls 30654
# nono 44188
# villainies 69364
# sorted 59853
# mashed 39544
# airplay 1263
# catwomanly 9911
# pullover 50665
# rampages 51550
# scholarship 56125
# mckimson 40048
# corri 13679
# finns 23282
# bondarchuk 7112
# frolics 24761
# childs 10837
# cinemagic 11233
# psychopath 50540
# becase 5295
# qualitatively 51003
# leathal 36509
# numspa 44527
# untill 68225
# rei 52657
# scattering 55959
# dinosaurs 17220
# logans 37602
# ports 49146
# sainik 55257
# measurably 40169
# touched 65550
# malay 38805
# enables 20335
# blaster 6508
# noisily 44127
# bloodiest 6686
# riot 54050
# hellenlotter 29020
# stagey 60766
# endeth 20435
# librarianship 36994
# despised 16580
# meh 40339
# oldboy 45072
# junctures 34158
# furnishing 24992
# middle 40923
# bick 6054
# eaters 19458
# ashtray 3385
# speculate 60174
# zeons 72492
# hortense 30210
# antonionian 2540
# inspite 32329
# seiter 56765
# airplanes 1262
# servents 57091
# studly 61838
# ttss 66470
# transacting 65785
# drumbeat 18917
# gunga 27669
# phone 47923
# commentary 12329
# michio 40880
# excruciating 21611
# leather 36510
# budjet 8318
# refugees 52530
# edina 19581
# alpine 1691
# tros 66307
# attacking 3724
# hugo 30471
# lawmen 36382
# knickers 35259
# toofan 65343
# trusts 66417
# bologna 7051
# ongoing 45181
# gridiron 27193
# appologise 2787
# answerman 2428
# dailey 15022
# chandeliers 10318
# wicket 70925
# mustangs 42863
# johnathin 33870
# serrault 57083
# hostages 30243
# vita 69552
# filmmaker 23163
# beardy 5221
# mvc 42919
# gravedancers 27043
# stiles 61285
# livable 37423
# suicide 62278
# figment 23082
# merciless 40587
# billie 6167
# mobile 41649
# meanderings 40139
# warhol 70078
# clyde 11791
# voltando 69678
# shaven 57488
# ardor 2983
# piling 48156
# rely 52872
# fighting 23079
# unfortuneatley 67613
# profusion 50102
# lugia 38101
# daninsky 15190
# geological 25766
# shockingest 57811
# devilishly 16781
# compleat 12519
# trope 66298
# uncynical 67257
# babelfish 4228
# rooming 54526
# misfilmed 41399
# plasticness 48470
# rogerson 54378
# lek 36678
# sash 55645
# timed 64957
# refutes 52547
# charecteres 10428
# trivilized 66264
# darkness 15275
# bricks 7865
# verde 69046
# stereotyped 61196
# gloopy 26342
# scattershot 55961
# mosfilm 42282
# unrevealed 68070
# purchasing 50781
# patriotic 46953
# socking 59515
# promised 50182
# berliner 5795
# nad 43029
# naughtier 43321
# intervened 32677
# discovers 17463
# wrightly 71743
# aured 3878
# mildred 41039
# totin 65534
# rique 54084
# alexa 1460
# diffring 17055
# tranquil 65778
# sensationally 56900
# pazienza 47074
# effie 19688
# banter 4722
# atherton 3645
# geico 25609
# strieber 61694
# rewrites 53756
# linaker 37209
# wouldve 71655
# rages 51371
# bombsight 7098
# gunslinging 27705
# sickroom 58163
# mallory 38870
# obscenity 44733
# arlington 3090
# disclosure 17414
# impelled 31281
# shandy 57377
# naidu 43068
# conifer 12930
# marshalls 39440
# vieght 69281
# indra 31837
# bobbi 6880
# somersaulting 59697
# exalted 21496
# slayer 58856
# whistleblowing 70786
# ebbs 19471
# pitying 48355
# palliates 46354
# steinmann 61138
# pandora 46429
# shakespearen 57311
# scampers 55877
# safeguard 55202
# bouncers 7445
# rutkay 55024
# immitating 31210
# luthien 38246
# ctu 14626
# ritt 54120
# animatrix 2298
# icebox 30866
# cower 13970
# myddleton 42935
# talkier 63422
# snicket 59328
# hassles 28533
# progrmmer 50128
# havin 28637
# requisites 53258
# nel 43567
# nadine 43038
# mystery 42973
# demure 16207
# canerday 9203
# valor 68703
# lindum 37237
# sperms 60234
# eustache 21303
# steampile 61077
# sequiter 57009
# doggone 18138
# pakage 46302
# allergies 1572
# mystified 42979
# mazovia 39882
# deputy 16400
# jbj 33520
# fehmiu 22740
# litres 37402
# hilltop 29485
# wip 71205
# deodorant 16302
# backcountry 4286
# stoumen 61507
# cotten 13789
# rumoured 54930
# afield 980
# thudding 64758
# conceptwise 12686
# profligacy 50088
# faaaaaabulous 22068
# entente 20681
# retainer 53508
# choice 10941
# lube 38022
# safaris 55196
# tokyos 65224
# reached 51899
# prove 50393
# idiosyncracies 30944
# rethought 53539
# jobbing 33811
# hito 29645
# nancy 43138
# corto 13716
# jekyll 33582
# mariah 39274
# dof 18120
# reacting 51905
# minister 41237
# overcomes 45875
# statesmanlike 60997
# assessments 3489
# collie 12107
# doinel 18162
# yomada 72190
# detach 16634
# robinon 54258
# telecommunication 63914
# damned 15116
# cashiers 9705
# specimen 60147
# skinamax 58694
# icon 30890
# seafood 56510
# summer 62358
# adoration 769
# someday 59685
# defensa 15836
# pranced 49405
# splatter 60371
# porcupines 49070
# frider 24664
# perishable 47482
# kitten 35146
# surmising 62677
# nickson 43857
# fubar 24831
# manning 39099
# sideliners 58182
# usurious 68522
# bachlor 4275
# indomitable 31831
# vuissa 69765
# nakatomi 43102
# equivalence 20920
# explicitly 21827
# waved 70267
# posher 49168
# stylist 61934
# penis 47303
# atom 3691
# schygula 56206
# troops 66296
# invests 32847
# gojitmal 26521
# chaimsaw 10230
# seeded 56681
# oneiros 45172
# consumingly 13171
# contemperaneous 13207
# wannabe 70033
# pressly 49724
# damaged 15086
# kramer 35518
# thunderbirds 64792
# boulange 7433
# varda 68814
# defer 15845
# sunjay 62412
# standing 60867
# liberia 36981
# vit 69551
# grover 27402
# bittorrent 6336
# gloss 26355
# motored 42367
# orna 45540
# mileu 41047
# emitting 20230
# mulkurul 42622
# gutsy 27753
# insulted 32411
# succinctness 62158
# nicco 43815
# extend 21924
# gutters 27760
# hodge 29731
# whitey 70818
# greenberg 27110
# kindsa 35019
# hymen 30755
# adorning 780
# shilling 57679
# longwinded 37720
# liberally 36971
# desalvo 16461
# telepathic 63940
# resists 53357
# orson 45562
# laughometer 36305
# rues 54859
# playwrights 48540
# essenay 21153
# athelny 3639
# haft 27906
# haff 27905
# clonkers 11690
# frazee 24506
# fikret 23100
# compassionnate 12464
# pandemic 46419
# troll 66278
# thoroughfare 64635
# rubberneck 54812
# cohesion 11983
# wassup 70175
# tamizh 63481
# chamberlains 10286
# ladakh 35826
# tokes 65220
# interesting 32536
# infallibility 31920
# thunderball 64790
# britsh 7991
# bhisti 6021
# stacks 60741
# andersons 2144
# jutra 34224
# hanzo 28270
# vein 68941
# overwork 46101
# bites 6322
# quizzical 51208
# ballarat 4544
# carnelutti 9533
# crewmemebers 14268
# peopling 47356
# championships 10302
# linesmen 37255
# dismissed 17627
# misuse 41567
# selected 56783
# sauce 55737
# cleanly 11515
# loathsome 37509
# clatch 11470
# fetchingly 22937
# rings 54032
# mathematically 39703
# staff 60748
# crowd 14485
# vehicle 68933
# most 42303
# winningham 71177
# resigning 53343
# clerical 11562
# critically 14360
# wussies 71826
# thundercats 64795
# forrests 24221
# biao 6034
# quiver 51198
# zhigang 72520
# teresa 64142
# electecuted 19876
# landfall 36024
# spriggs 60543
# kairo 34310
# manpower 39119
# adolescent 749
# swabby 62833
# brandos 7642
# horrror 30185
# endurable 20460
# bobcat 6890
# streamline 61622
# dachau 14977
# videocassette 69253
# tetsukichi 64274
# iene 30981
# begrudging 5453
# someplaces 59693
# imposable 31370
# zest 72506
# fourthly 24327
# crreeepy 14500
# emission 20226
# jeffrey 33570
# slots 59026
# second 56606
# whitepages 70810
# wagging 69854
# disinfecting 17569
# nofth 44111
# sargoth 55619
# saurious 55757
# rohm 54392
# karlsson 34457
# pitchforks 48326
# aleck 1435
# bestselling 5891
# lacey 35792
# idrissa 30971
# jugde 34089
# depressing 16382
# umbrellas 66972
# waverly 70273
# oliver 45097
# modernity 41709
# maar 38336
# privleged 49936
# environmentalism 20802
# consequent 13036
# demarcation 16116
# irrevocable 33017
# deply 16352
# auh 3863
# voguing 69633
# cartooning 9647
# boilerplate 6998
# psalms 50473
# sharkish 57439
# leanne 36482
# neurotically 43685
# inhaling 32097
# outa 45679
# lampidorrans 35986
# fixation 23409
# trespass 66091
# accidents 331
# levitate 36905
# miranda 41308
# base 4958
# reminiscences 52936
# possession 49194
# merde 40597
# frontiers 24772
# jersey 33661
# helfer 28995
# efenstor 19662
# gringoire 27266
# ized 33211
# eastwoods 19450
# elwes 20083
# althogh 1740
# dabbing 14967
# sanctifies 55445
# ferdinandvongalitzien 22856
# experimentalism 21792
# arsonists 3235
# reverses 53658
# rogerebert 54376
# testifies 64251
# creatures 14190
# petiot 47709
# bedeviled 5333
# sanada 55437
# eward 21464
# barging 4831
# templeton 64017
# policier 48845
# nandu 43145
# unglued 67649
# closups 11707
# usc 68482
# reentered 52447
# shamalyan 57344
# aishu 1284
# jaggers 33305
# kmc 35234
# fruedian 24796
# sandbox 55465
# peace 47088
# your 72252
# discourage 17451
# druing 18914
# entitlements 20733
# killshot 34967
# loathed 37504
# mpkdh 42505
# verbalizations 69032
# lorry 37837
# wingers 71149
# happenstance 28287
# ditties 17915
# maniacal 39030
# dicks 16971
# crimedies 14288
# promting 50204
# stove 61511
# discribe 17477
# shihito 57667
# otoh 45647
# claudia 11477
# braininess 7598
# owe 46109
# jubilee 34056
# shoulda 57931
# align 1518
# repository 53168
# solti 59664
# witless 71311
# fictionalized 23010
# pepsi 47378
# gate 25473
# stimulating 61306
# assays 3462
# setback 57116
# enjoyment 20570
# driller 18812
# regurgitating 52629
# buddwing 8307
# hukum 30485
# objectified 44682
# moving 42479
# intrested 32731
# outsiders 45793
# wreathed 71709
# sedative 56659
# imbreds 31152
# pojar 48798
# theater 64373
# twangy 66700
# cultivate 14708
# compare 12447
# exclusion 21590
# snazzier 59297
# broddrick 8038
# anupam 2559
# unformed 67603
# cline 11629
# treating 66015
# mealy 40132
# electrocution 19901
# potemkin 49259
# stowing 61516
# unhackneyed 67663
# lathered 36249
# squadrons 60617
# halifax 28024
# katharyn 34531
# innes 32181
# explores 21856
# proceeding 49990
# anothwer 2412
# fronts 24776
# kaoru 34403
# intenseness 32468
# eventully 21365
# silliness 58321
# kleenex 35181
# octogenarian 44871
# affordable 960
# confiscation 12851
# undertext 67403
# gance 25284
# bullish 8430
# generalizing 25662
# ina 31465
# delicacies 16030
# beautify 5283
# fothergill 24287
# chunk 11142
# buying 8747
# rowe 54752
# popstar 49040
# estabrook 21169
# orlac 45532
# throwback 64738
# expatiate 21745
# sumin 62340
# deflowers 15906
# aghhh 1086
# pallette 46353
# doghi 18141
# interrelations 32630
# stealin 61064
# senator 56863
# dandyish 15157
# remember 52913
# whoo 70868
# improbability 31425
# horticultural 30213
# jenifer 33602
# corundum 13717
# coda 11907
# uppercrust 68366
# primal 49851
# reily 52682
# stepford 61165
# buzzes 8761
# fairhaired 22195
# christmassy 11069
# intentions 32485
# mantan 39133
# blossom 6730
# caricaturing 9477
# bhatt 6012
# unacted 67018
# rhetoric 53787
# dogfights 18128
# rubberized 54811
# vertes 69123
# impersonators 31312
# adamantium 589
# garber 25360
# thanked 64335
# repast 53080
# spraypainted 60532
# catherine 9877
# streptomycin 61660
# tso 66448
# mgs 40833
# seachange 56505
# gone 26600
# windows 71130
# spared 60042
# embezzler 20149
# lecarre 36537
# cajuns 8929
# kryukova 35614
# yvelines 72333
# fuhrer 24869
# repartee 53078
# rolls 54432
# sweary 62906
# shivers 57787
# anjela 2320
# clams 11394
# devdas 16743
# michener 40876
# compounding 12592
# decider 15639
# bonhomie 7141
# gymnasts 27807
# join 33888
# panhandlers 46447
# severed 57164
# bronstein 8076
# oops 45251
# leroux 36807
# repulsed 53233
# chet 10736
# bulu 8448
# misquote 41480
# zungia 72683
# claymore 11503
# brough 8123
# let 36839
# acclimation 337
# knockers 35290
# schtupping 56178
# enthusiastic 20714
# conservationist 13041
# taylors 63750
# bucketfuls 8275
# contradictorily 13304
# nightclubs 43916
# widower 70949
# clouseau 11726
# arado 2888
# usses 68512
# scientific 56213
# deano 15498
# symbiont 63094
# profiling 50080
# pricks 49831
# recall 52102
# milanese 41027
# keefs 34635
# robotically 54269
# tavern 63718
# fickleness 23000
# dallenbach 15065
# anthropocentric 2464
# breats 7773
# syrianna 63208
# nashville 43237
# morsheba 42238
# pane 46431
# cognizant 11964
# futher 25024
# explained 21814
# tabloidesque 63250
# frokost 24757
# valentine 68659
# sibblings 58125
# unskilled 68134
# fllow 23703
# burrier 8601
# teazle 63824
# sulked 62311
# excluding 21589
# revival 53696
# tensdoorp 64097
# lecture 36548
# mongooses 41901
# rhetoromance 53792
# redack 52322
# voight 69647
# blanks 6492
# maratonci 39196
# uncoventional 67241
# gruntled 27464
# mckoy 40051
# singin 58456
# sayre 55835
# rda 51885
# psychotic 50553
# escort 21081
# hannan 28253
# instigate 32353
# revised 53678
# straithrain 61548
# growl 27409
# lakehurst 35915
# perlman 47496
# loather 37505
# continue 13266
# samandar 55386
# stack 60737
# wimsey 71098
# detection 16652
# pegg 47227
# permanente 47501
# chandelere 10316
# specialise 60118
# slapsticks 58818
# hubby 30421
# soaking 59451
# stinson 61335
# uplift 68355
# cary 9675
# bhosle 6025
# squeazy 60657
# spatula 60084
# fugitives 24863
# sci 56208
# grauman 27041
# allot 1597
# timebomb 64953
# racoons 51290
# tao 63559
# generously 25682
# egress 19746
# gungan 27670
# ambiguities 1849
# fcked 22647
# trouncing 66336
# butterflies 8722
# crotches 14473
# overbite 45860
# herve 29262
# whilst 70730
# deputising 16397
# seamanship 56527
# thirlby 64577
# veils 68940
# whitehall 70803
# biery 6081
# tunney 66570
# caw 9982
# oklahoma 45056
# speedway 60200
# yugonostalgic 72292
# sheepishness 57537
# woman 71411
# refuses 52542
# intercuts 32525
# crisscross 14344
# lag 35871
# bonfires 7135
# gough 26793
# stiers 61261
# gothenburg 26774
# marc 39205
# pretender 49760
# waterman 70235
# extrovert 22018
# bloodymonday 6712
# chips 10896
# riccardo 53847
# aegerter 880
# montaged 41980
# oregonian 45445
# bay 5138
# messily 40705
# depersonalization 16333
# kazakhstan 34599
# manitoba 39070
# ziltch 72549
# exaggeratedly 21489
# fisheris 23359
# deepti 15780
# calahan 8936
# erupts 21040
# prepoire 49645
# slovenians 59039
# kitrosser 35140
# asbury 3334
# counterattack 13844
# doones 18349
# ria 53825
# terrorises 64205
# swordsmen 63058
# partes 46753
# rollup 54433
# spasm 60070
# parapsychologists 46609
# aoki 2599
# gurgling 27716
# despaaaaaair 16554
# experiencing 21787
# suspenseful 62774
# canby 9160
# multifaceted 42650
# kuntar 35666
# patching 46889
# peacefully 47091
# fishermen 23361
# slighter 58940
# parakeet 46569
# trashin 65933
# kali 34337
# prominant 50175
# filthier 23192
# shekhar 57565
# daring 15253
# saucy 55742
# recessive 52149
# alllll 1589
# loane 37496
# splashdown 60364
# utmost 68551
# grumps 27455
# substances 62074
# civility 11354
# toru 65490
# jonestown 33936
# dastor 15340
# soon 59771
# carn 9523
# normalos 44260
# spinnaker 60307
# representation 53175
# porns 49092
# fla 23431
# matkondar 39727
# backwoods 4336
# objectifier 44683
# eastman 19445
# rderung 51887
# distractions 17871
# outskirts 45798
# lvia 38273
# portman 49129
# alright 1697
# humpback 30577
# mcnaughton 40086
# merilu 40616
# sacred 55144
# mourby 42411
# deemed 15764
# spook 60459
# entrails 20743
# knappertsbusch 35239
# aving 4057
# naturedly 43308
# chore 10998
# airspace 1271
# unkind 67801
# winded 71115
# cloudscape 11723
# whining 70748
# couture 13936
# amateurishly 1814
# proceeds 49992
# clair 11378
# unparrallel 67938
# projectiles 50141
# overdoing 45891
# clickety 11589
# kernels 34766
# nolan 44132
# jello 33588
# nfny 43785
# vitam 69557
# object 44679
# nearing 43409
# hospitals 30238
# unachieving 67015
# cin 11209
# goosebumps 26691
# velvety 68964
# gallop 25224
# overcoat 45872
# faulk 22586
# explodes 21832
# runtime 54953
# rewinded 53743
# abode 138
# hunh 30614
# expresses 21896
# redfield 52353
# zeman 72477
# miraglia 41303
# hollister 29828
# dobkins 18032
# case 9687
# contend 13226
# canutt 9273
# jungian 34163
# awaaaaay 4084
# moneys 41886
# probing 49973
# telenovelas 63937
# foretaste 24124
# kohara 35355
# banged 4669
# sal 55285
# searing 56553
# stretchs 61671
# yez 72134
# idiotically 30953
# devalues 16733
# pavlovian 47030
# selfpity 56801
# simba 58353
# innovatory 32202
# inducted 31843
# probabilistic 49955
# albot 1398
# realated 51950
# ravaged 51799
# berserkers 5835
# foulmouthed 24300
# suoi 62444
# wayback 70290
# bested 5878
# cringe 14306
# gurkha 27720
# resi 53323
# inhumane 32115
# byways 8806
# coconut 11900
# magnanimous 38604
# methodology 40778
# gobsmacked 26445
# ruling 54901
# enumerates 20777
# leadenly 36454
# enslaved 20648
# chopping 10986
# fontanelles 23975
# smithee 59182
# geeeee 25589
# burrs 8610
# contemplation 13212
# overindulgent 45949
# suprises 62633
# loathsomeness 37510
# shrewed 58006
# kilometers 34974
# what 70647
# cowering 13972
# machacek 38399
# omnipresent 45151
# goddammit 26457
# delicto 16039
# gags 25132
# towing 65611
# tranvestites 65914
# proust 50390
# roadie 54193
# marielle 39286
# suppress 62613
# purile 50803
# mooning 42056
# bodybuilding 6928
# jayant 33499
# crawler 14141
# outshone 45789
# philosophic 47888
# monorail 41944
# chucking 11113
# hoops 30060
# tiburon 64844
# humped 30580
# skarsg 58614
# frederik 24542
# aguirre 1144
# filmes 23147
# querelle 51097
# kimiko 34991
# argila 3016
# san 55436
# redundant 52414
# lousier 37910
# vowing 69745
# egyption 19753
# carving 9672
# relates 52774
# wellingtonian 70512
# unprocessed 67977
# wolfen 71390

# %%
def extract_BoW_features(words_train, words_test, vocabulary_size=5000,
                         cache_dir=cache_dir, cache_file="bow_features.pkl"):
    """Extract Bag-of-Words for a given set of documents, already preprocessed into words."""
    
    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = joblib.load(f)
            print("Read features from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # TODO: Fit a vectorizer to training documents and use it to transform thema
        # NOTE: Training documents have already been preprocessed and tokenized into words;
        #       pass in dummy functions to skip those steps, e.g. preprocessor=lambda x: x
        vectorizer =  CountVectorizer(max_features= vocabulary_size, preprocessor=lambda x : x)
        features_train = ?

        # TODO: Apply the same vectorizer to transform the test documents (ignore unknown words)
        features_test = ?
        
        # NOTE: Remember to convert the features using .toarray() for a compact representation
        
        # Write to cache file for future runs (store vocabulary as well)
        if cache_file is not None:
            vocabulary = vectorizer.vocabulary_
            cache_data = dict(features_train=features_train, features_test=features_test,
                             vocabulary=vocabulary)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                joblib.dump(cache_data, f)
            print("Wrote features to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        features_train, features_test, vocabulary = (cache_data['features_train'],
                cache_data['features_test'], cache_data['vocabulary'])
    
    # Return both the extracted features as well as the vocabulary
    return features_train, features_test, vocabulary


# Extract Bag of Words features for both training and test datasets
features_train, features_test, vocabulary = extract_BoW_features(words_train, words_test)

# Inspect the vocabulary that was computed
print("Vocabulary: {} words".format(len(vocabulary)))

import random
print("Sample words: {}".format(random.sample(list(vocabulary.keys()), 8)))

# Sample
print("\n--- Preprocessed words ---")
print(words_train[5])
print("\n--- Bag-of-Words features ---")
print(features_train[5])
print("\n--- Label ---")
print(labels_train[5])(
)

# %% [markdown]
# Let's try to visualize the Bag-of-Words feature vector for one of our training documents.

# %%
# Plot the BoW feature vector for a training document
plt.plot(features_train[5,:])
plt.xlabel('Word')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Question: Reflecting on Bag-of-Words feature representation
#
# What is the average sparsity level of BoW vectors in our training set? In other words, on average what percentage of entries in a BoW feature vector are zero?
#
# #### Answer:
#
# ...
#
# ### Zipf's law
#
# [Zipf's law](https://en.wikipedia.org/wiki/Zipf%27s_law), named after the famous American linguist George Zipf, is an empirical law stating that given a large collection of documents, the frequency of any word is inversely proportional to its rank in the frequency table. So the most frequent word will occur about twice as often as the second most frequent word, three times as often as the third most frequent word, and so on. In the figure below we plot number of appearances of each word in our training set against its rank.

# %%
# Find number of occurrences for each word in the training set
word_freq = features_train.sum(axis=0)

# Sort it in descending order
sorted_word_freq = np.sort(word_freq)[::-1]

# Plot 
plt.plot(sorted_word_freq)
plt.gca().set_xscale('log')
plt.gca().set_yscale('log')
plt.xlabel('Rank')
plt.ylabel('Number of occurrences')
plt.show()

# %% [markdown]
# #### Question: Zipf's law
#
# What is the total number of occurrences of the most frequent word? What is the the total number of occurrences of the second most frequent word? Do your numbers follow  Zipf's law? If not, why?
#
# #### Answer:
#
# ...
#
# ### TODO: Normalize feature vectors
#
# Bag-of-Words features are intuitive to understand as they are simply word counts. But counts can vary a lot, and potentially throw off learning algorithms later in the pipeline. So, before we proceed further, let's normalize the BoW feature vectors to have unit length.
#
# This makes sure that each document's representation retains the unique mixture of feature components, but prevents documents with large word counts from dominating those with fewer words.

# %%
import sklearn.preprocessing as pr

# TODO: Normalize BoW features in training and test set

# %% [markdown]
# ## Step 4: Classification using BoW features
#
# Now that the data has all been properly transformed, we can feed it into a classifier. To get a baseline model, we train a Naive Bayes classifier from scikit-learn (specifically, [`GaussianNB`](http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.GaussianNB.html)), and evaluate its accuracy on the test set.

# %%
from sklearn.naive_bayes import GaussianNB

# TODO: Train a Guassian Naive Bayes classifier
clf1 = ?

# Calculate the mean accuracy score on training and test sets
print("[{}] Accuracy: train = {}, test = {}".format(
        clf1.__class__.__name__,
        clf1.score(features_train, labels_train),
        clf1.score(features_test, labels_test)))

# %% [markdown]
# Tree-based algorithms often work quite well on Bag-of-Words as their highly discontinuous and sparse nature is nicely matched by the structure of trees. As your next task, you will try to improve on the Naive Bayes classifier's performance by using scikit-learn's Gradient-Boosted Decision Tree classifer.
#
# ### TODO: Gradient-Boosted Decision Tree classifier
#
# Use [`GradientBoostingClassifier`](http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingClassifier.html) from scikit-learn to classify the BoW data. This model has a number of parameters. We use default parameters for some of them and pre-set the rest for you, except one: `n_estimators`. Find a proper value for this hyperparameter, use it to classify the data, and report how much improvement you get over Naive Bayes in terms of accuracy.
#
# > **Tip**: Use a model selection technique such as cross-validation, grid-search, or an information criterion method, to find an optimal value for the hyperparameter.

# %%
from sklearn.ensemble import GradientBoostingClassifier

n_estimators = ?

def classify_gboost(X_train, X_test, y_train, y_test):        
    # Initialize classifier
    clf = GradientBoostingClassifier(n_estimators=n_estimators, learning_rate=1.0, max_depth=1, random_state=0)

    # TODO: Classify the data using GradientBoostingClassifier
    
    # TODO(optional): Perform hyperparameter tuning / model selection
    
    # TODO: Print final training & test accuracy
    
    # Return best classifier model
    return clf


clf2 = classify_gboost(features_train, features_test, labels_train, labels_test)

# %% [markdown]
# ### TODO: Adverserial testing
#
# Write a short movie review to trick your machine learning model! That is, a movie review with a clear positive or negative sentiment that your model will classify incorrectly.
#
# > **Hint**: You might want to take advantage of the biggest weakness of the Bag-of-Words scheme!

# %%
# TODO: Write a sample review and set its true sentiment
my_review = "..."
true_sentiment = ''  # sentiment must be 'pos' or 'neg'

# TODO: Apply the same preprocessing and vectorizing steps as you did for your training data

# TODO: Then call your classifier to label it

# %% [markdown]
# ## Step 5: Switching gears - RNNs
#
# We just saw how the task of sentiment analysis can be solved via a traditional machine learning approach: BoW + a nonlinear classifier. We now switch gears and use Recurrent Neural Networks, and in particular LSTMs, to perform sentiment analysis in Keras. Conveniently, Keras has a built-in [IMDb movie reviews dataset](https://keras.io/datasets/#imdb-movie-reviews-sentiment-classification) that we can use, with the same vocabulary size.

# %%
from keras.datasets import imdb  # import the built-in imdb dataset in Keras

# Set the vocabulary size
vocabulary_size = 5000

# Load in training and test data (note the difference in convention compared to scikit-learn)
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=vocabulary_size)
print("Loaded dataset with {} training samples, {} test samples".format(len(X_train), len(X_test)))

# %%
# Inspect a sample review and its label
print("--- Review ---")
print(X_train[7])
print("--- Label ---")
print(y_train[7])

# %% [markdown]
# Notice that the label is an integer (0 for negative, 1 for positive), and the review itself is stored as a sequence of integers. These are word IDs that have been preassigned to individual words. To map them back to the original words, you can use the dictionary returned by `imdb.get_word_index()`.

# %%
# Map word IDs back to words
word2id = imdb.get_word_index()
id2word = {i: word for word, i in word2id.items()}
print("--- Review (with words) ---")
print([id2word.get(i, " ") for i in X_train[7]])
print("--- Label ---")
print(y_train[7])

# %% [markdown]
# Unlike our Bag-of-Words approach, where we simply summarized the counts of each word in a document, this representation essentially retains the entire sequence of words (minus punctuation, stopwords, etc.). This is critical for RNNs to function. But it also means that now the features can be of different lengths!
#
# #### Question: Variable length reviews
#
# What is the maximum review length (in terms of number of words) in the training set? What is the minimum?
#
# #### Answer:
#
# ...
#
#
# ### TODO: Pad sequences
#
# In order to feed this data into your RNN, all input documents must have the same length. Let's limit the maximum review length to `max_words` by truncating longer reviews and padding shorter reviews with a null value (0). You can accomplish this easily using the [`pad_sequences()`](https://keras.io/preprocessing/sequence/#pad_sequences) function in Keras. For now, set `max_words` to 500.

# %%
from keras.preprocessing import sequence

# Set the maximum number of words per document (for both training and testing)
max_words = 500

# TODO: Pad sequences in X_train and X_test

# %% [markdown]
# ### TODO: Design an RNN model for sentiment analysis
#
# Build your model architecture in the code cell below. We have imported some layers from Keras that you might need but feel free to use any other layers / transformations you like.
#
# Remember that your input is a sequence of words (technically, integer word IDs) of maximum length = `max_words`, and your output is a binary sentiment label (0 or 1).

# %%
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense, Dropout

# TODO: Design your model
model = ?

print(model.summary())

# %% [markdown]
# #### Question: Architecture and parameters
#
# Briefly describe your neural net architecture. How many model parameters does it have that need to be trained?
#
# #### Answer:
#
# ...
#
# ### TODO: Train and evaluate your model
#
# Now you are ready to train your model. In Keras world, you first need to _compile_ your model by specifying the loss function and optimizer you want to use while training, as well as any evaluation metrics you'd like to measure. Specify the approprate parameters, including at least one metric `'accuracy'`.

# %%
# TODO: Compile your model, specifying a loss function, optimizer, and metrics

# %% [markdown]
# Once compiled, you can kick off the training process. There are two important training parameters that you have to specify - **batch size** and **number of training epochs**, which together with your model architecture determine the total training time.
#
# Training may take a while, so grab a cup of coffee, or better, go for a hike! If possible, consider using a GPU, as a single training run can take several hours on a CPU.
#
# > **Tip**: You can split off a small portion of the training set to be used for validation during training. This will help monitor the training process and identify potential overfitting. You can supply a validation set to `model.fit()` using its `validation_data` parameter, or just specify `validation_split` - a fraction of the training data for Keras to set aside for this purpose (typically 5-10%). Validation metrics are evaluated once at the end of each epoch.

# %%
# TODO: Specify training parameters: batch size and number of epochs
batch_size = ?
num_epochs = ?

# TODO(optional): Reserve/specify some training data for validation (not to be used for training)

# TODO: Train your model

# %%
# Save your model, so that you can quickly load it in future (and perhaps resume training)
model_file = "rnn_model.h5"  # HDF5 file
model.save(os.path.join(cache_dir, model_file))

# Later you can load it using keras.models.load_model()
#from keras.models import load_model
#model = load_model(os.path.join(cache_dir, model_file))

# %% [markdown]
# Once you have trained your model, it's time to see how well it performs on unseen test data.

# %%
# Evaluate your model on the test set
scores = model.evaluate(X_test, y_test, verbose=0)  # returns loss and other metrics specified in model.compile()
print("Test accuracy:", scores[1])  # scores[1] should correspond to accuracy if you passed in metrics=['accuracy']

# %% [markdown]
# #### Question: Comparing RNNs and Traditional Methods
#
# How well does your RNN model perform compared to the BoW + Gradient-Boosted Decision Trees?
#
# #### Answer:
#
# ...
#
# ## Extensions
#
# There are several ways in which you can build upon this notebook. Each comes with its set of challenges, but can be a rewarding experience.
#
# - The first thing is to try and improve the accuracy of your model by experimenting with different architectures, layers and parameters. How good can you get without taking prohibitively long to train? How do you prevent overfitting?
#
# - Then, you may want to deploy your model as a mobile app or web service. What do you need to do in order to package your model for such deployment? How would you accept a new review, convert it into a form suitable for your model, and perform the actual prediction? (Note that the same environment you used during training may not be available.)
#
# - One simplification we made in this notebook is to limit the task to binary classification. The dataset actually includes a more fine-grained review rating that is indicated in each review's filename (which is of the form `<[id]_[rating].txt>` where `[id]` is a unique identifier and `[rating]` is on a scale of 1-10; note that neutral reviews > 4 or < 7 have been excluded). How would you modify the notebook to perform regression on the review ratings? In what situations is regression more useful than classification, and vice-versa?
#
# Whatever direction you take, make sure to share your results and learnings with your peers, through blogs, discussions and participating in online competitions. This is also a great way to become more visible to potential employers!
